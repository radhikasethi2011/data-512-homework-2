# %% [markdown]
# ### Importing Necessary Libraries
# In this cell, we import all the essential libraries that we'll need for data processing, analysis, and visualization. These libraries include:
# - `numpy` for numerical operations
# - `pandas` for handling dataframes
# - `matplotlib` for plotting results
# - `tabulate` for displaying clean tables
# - `requests` for fetching data via API (if applicable)

# %%
import pandas as pd 
import requests  
import time  
import json
# Out:
# /Users/radhikasethi/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ### Loading the Datasets
# In this cell, we load the datasets that will be used throughout the analysis. These include:
# 1. `politicians_with_quality.csv` - A dataset containing details about Wikipedia articles on politicians, including revision IDs and quality scores.
# 2. `population_by_country_AUG.2024.csv` - A dataset providing population data by country, which will be used for calculating articles per capita.
#
# We use `pandas` to load these CSV files into dataframes for further processing.

# %%
# Loading the datasets
politicians_df = pd.read_csv('/Users/radhikasethi/Documents/github/data-512-homework-2/data/politicians_with_quality.csv')
population_df = pd.read_csv('/Users/radhikasethi/Documents/github/data-512-homework-2/data/population_by_country_AUG.2024.csv')

# Displaying the first few rows to ensure the data has been loaded correctly
print("Politicians Data:")
print(politicians_df.head())

print("\nPopulation Data:")
print(population_df.head())
# Out:
# Politicians Data Preview:
#                    name                                                url  \
# 0        Majah Ha Adrif       https://en.wikipedia.org/wiki/Majah_Ha_Adrif
# 1     Haroon al-Afghani    https://en.wikipedia.org/wiki/Haroon_al-Afghani
# 2           Tayyab Agha          https://en.wikipedia.org/wiki/Tayyab_Agha
# 3  Khadija Zahra Ahmadi  https://en.wikipedia.org/wiki/Khadija_Zahra_Ah...
# 4        Aziza Ahmadyar       https://en.wikipedia.org/wiki/Aziza_Ahmadyar
#
#        country
# 0  Afghanistan
# 1  Afghanistan
# 2  Afghanistan
# 3  Afghanistan
# 4  Afghanistan
#
# Population Data Preview:
#          Geography  Population
# 0            WORLD      8009.0
# 1           AFRICA      1453.0
# 2  NORTHERN AFRICA       256.0
# 3          Algeria        46.8
# 4            Egypt       105.2

# %% [markdown]
# ### Standardizing and Cleaning Country Names
# Before merging the datasets, we need to ensure that country names are consistent across both datasets. This cell:
# 1. Converts country names to lowercase and removes extra spaces in both the politicians and population datasets.
# 2. Applies a mapping dictionary (`name_map`) to standardize specific country names (e.g., different variations of China and Guinea-Bissau).
# 3. Ensures that merging will occur seamlessly later on by standardizing names between the datasets.

# %%
# Checking for duplicates based on all columns in the politicians dataset
duplicate_politicians_all = politicians_df[politicians_df.duplicated()]
print(f"Total duplicate rows (all columns): {len(duplicate_politicians_all)}")

# Checking for duplicates based on just 'name' and 'url' columns
duplicate_politicians_name = politicians_df[politicians_df.duplicated(subset=['name'])]
duplicate_politicians_url = politicians_df[politicians_df.duplicated(subset=['url'])]
print(f"Duplicate rows based on 'name': {len(duplicate_politicians_name)}")
print(f"Duplicate rows based on 'url': {len(duplicate_politicians_url)}")

# Combine duplicate data based on name and url and export to a CSV file
combined_duplicates = pd.concat([duplicate_politicians_name, duplicate_politicians_url]).drop_duplicates()
combined_duplicates.to_csv('../data/combined_duplicates_politicians.csv', index=False)
print("Combined duplicates have been saved to 'combined_duplicates_politicians.csv'")
# Out:
# Total duplicate rows (all columns): 0
# Duplicate rows based on 'name': 44
# Duplicate rows based on 'url': 44
# Combined duplicates have been saved to 'combined_duplicates_politicians.csv'

# %%
# Adding a helper column to identify regions (uppercase 'Geography' means a region)
population_df['is_region'] = population_df['Geography'].apply(lambda x: x.isupper())

# Split the dataframe into two: regions and countries
df_region = population_df[population_df['is_region'] == True].copy()
df_country = population_df[population_df['is_region'] == False].copy()

# Dropping the helper column after the split
df_region.drop(columns=['is_region'], inplace=True)
df_country.drop(columns=['is_region'], inplace=True)

# View the country dataset to verify the operation
print(f"Total countries: {df_country.count()[0]}")
# Out:
# Total countries: 209
# /var/folders/x8/4fwkd70s40s_wrt2mnhq6rdw0000gn/T/ipykernel_72795/1651045841.py:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(f"Total countries: {df_country.count()[0]}")

# %% [markdown]
# ### Fetching Wikipedia Article Revision IDs
# In this section, we use the Wikipedia API to retrieve the `revision_id` for a list of Wikipedia articles. The `revision_id` is essential for tracking the latest version of an article.
#
# Key points:
# - We utilize the MediaWiki API to query Wikipedia for page information.
# - The function `get_revision_id` is used to fetch the latest revision ID for each article title.
# - To avoid exceeding API rate limits, a throttle delay is introduced between requests.

# %%
import requests
import time
import logging

# API URL for Wikipedia
API_URL = "https://en.wikipedia.org/w/api.php"
# Throttle time to avoid hitting the API too fast
API_THROTTLE = 0.7  # Adjusted for faster requests

# Headers for making requests to Wikipedia API
HEADERS = {
    'User-Agent': 'rsethi3@uw.edu, University Project - 2024'
}

# Template for page info request (this will be copied and modified per request)
PAGE_INFO_PARAMS = {
    "action": "query",
    "format": "json",
    "titles": "",  # Title will be added dynamically
    "prop": "info",
    "inprop": "url|talkid"
}

# This function requests page info for an article and retrieves the revision ID
def get_revision_id(article_title):
    # Copy the request template and add the article title
    params = PAGE_INFO_PARAMS.copy()
    params["titles"] = article_title
    
    # Throttle to respect API limits
    time.sleep(API_THROTTLE)
    
    try:
        # Make the request to the Wikipedia API
        response = requests.get(API_URL, headers=HEADERS, params=params)
        data = response.json()

        # Extract page info from the JSON response
        if 'query' in data:
            pages = data['query']['pages']
            for page_id, page_info in pages.items():
                return page_info.get("lastrevid", None)
        else:
            logging.error(f"Could not find 'query' in the response for {article_title}")
            return None
    except Exception as e:
        logging.error(f"Error fetching revision ID for {article_title}: {e}")
        return None

# %% [markdown]
# ### Setting up API Configuration
# Before making API requests to ORES (Objective Revision Evaluation Service), we need to configure the API endpoints and ensure we have the required libraries and setup. This cell:
# 1. Defines the ORES API base URL for fetching quality scores for Wikipedia articles.
# 2. Loads necessary libraries (`requests` for API calls and `json` for handling API responses).

# %%
# ORES API endpoint and model
ORES_URL = "https://ores.wikimedia.org/v3/scores/enwiki/"
ORES_MODEL = "wp10"  # Predicting quality

# Function to get quality score based on revision ID
def get_quality_prediction(article_title, revision_id):
    try:
        # Construct the ORES request URL with revision ID
        full_url = f"{ORES_URL}?models={ORES_MODEL}&revids={revision_id}"
        response = requests.get(full_url)

        # Check for successful response
        if response.status_code == 200:
            data = response.json()
            # Navigate through the JSON structure to extract the prediction
            return data['enwiki']['scores'][str(revision_id)]['wp10']['score']['prediction']
        else:
            logging.error(f"Failed to retrieve ORES quality score for {article_title} (revision: {revision_id})")
            return None
    except Exception as e:
        logging.error(f"Error retrieving ORES score for {article_title}: {e}")
        return None

# %% [markdown]
# ### Adding Revision IDs and Quality Scores to the Dataset
# In this section, we iterate through each row in the `politicians_df` DataFrame and:
# 1. Extract the article title from the URL.
# 2. Fetch the article's `revision_id` using the `get_revision_id` function.
# 3. Retrieve the ORES quality score using the `get_quality_prediction` function.
# 4. Log any errors or failed requests, saving them for review.
#
# The final dataset with both the `revision_id` and `quality_score` is saved, along with a log of articles that failed to fetch.

# %%
# Initialize an empty error log for articles that fail to get revision IDs or quality scores
error_log = []

# Add columns to store the revision ID and quality score in the DataFrame
politicians_df['revision_id'] = None
politicians_df['quality_score'] = None

# Iterate through each row (each politician) in the dataset
for index, row in politicians_df.iterrows():
    # Extract the article title from the Wikipedia URL (the last part of the URL)
    article_title = row['url'].split('/')[-1]
    logging.info(f"Processing {article_title}")

    # Step 1: Get the revision ID for the article
    revision_id = get_revision_id(article_title)
    
    if revision_id:
        # Step 2: If we successfully got a revision ID, fetch the quality score using ORES
        quality_score = get_quality_prediction(article_title, revision_id)
        politicians_df.at[index, 'revision_id'] = revision_id  # Store the revision ID
        politicians_df.at[index, 'quality_score'] = quality_score  # Store the quality score
    else:
        # If we couldn't retrieve the revision ID, log the article title in the error log
        error_log.append(article_title)

# Save the error log to a text file for review
with open('../data/ores_error_log.txt', 'w') as log_file:
    log_file.write("\n".join(error_log))

# Save the DataFrame (now with quality scores and revision IDs) to a CSV file
politicians_df.to_csv('../data/politicians_with_quality.csv', index=False)

# Calculate and log the error rate (percentage of articles that failed)
error_rate = len(error_log) / len(politicians_df)
logging.info(f"Error rate: {error_rate:.2%}")
# Out:
# 2024-10-14 00:17:25,088 - INFO - Processing Majah_Ha_Adrif
# 2024-10-14 00:17:27,373 - INFO - Processing Haroon_al-Afghani
# 2024-10-14 00:17:28,879 - INFO - Processing Tayyab_Agha
# 2024-10-14 00:17:30,243 - INFO - Processing Khadija_Zahra_Ahmadi
# 2024-10-14 00:17:31,674 - INFO - Processing Aziza_Ahmadyar
# 2024-10-14 00:17:33,214 - INFO - Processing Muqadasa_Ahmadzai
# 2024-10-14 00:17:35,121 - INFO - Processing Mohammad_Sarwar_Ahmedzai
# 2024-10-14 00:17:36,781 - INFO - Processing Amir_Muhammad_Akhundzada
# 2024-10-14 00:17:39,037 - INFO - Processing Nasrullah_Baryalai_Arsalai
# 2024-10-14 00:17:40,526 - INFO - Processing Abdul_Rahim_Ayoubi
# 2024-10-14 00:17:42,024 - INFO - Processing Ismael_Balkhi
# 2024-10-14 00:17:43,528 - INFO - Processing Abdul_Baqi_Turkistani
# 2024-10-14 00:17:44,977 - INFO - Processing Mohammad_Ghous_Bashiri
# 2024-10-14 00:17:46,361 - INFO - Processing Jan_Baz
# 2024-10-14 00:17:47,740 - INFO - Processing Bashir_Ahmad_Bezan
# 2024-10-14 00:17:49,039 - INFO - Processing Rafiullah_Bidar
# 2024-10-14 00:17:50,730 - INFO - Processing Mohammad_Siddiq_Chakari
# 2024-10-14 00:17:52,020 - INFO - Processing Cheragh_Ali_Cheragh
# 2024-10-14 00:17:53,576 - INFO - Processing Nasir_Ahmad_Durrani
# 2024-10-14 00:17:55,239 - INFO - Processing Muhammad_Hashim_Esmatullahi
# 2024-10-14 00:17:56,644 - INFO - Processing Ezatullah_(Nangarhar)
# 2024-10-14 00:17:58,030 - INFO - Processing Aimal_Faizi
# 2024-10-14 00:18:00,204 - INFO - Processing Gajinder_Singh_Safri
# 2024-10-14 00:18:01,672 - INFO - Processing Sharif_Ghalib
# 2024-10-14 00:18:03,325 - INFO - Processing Hashmat_Ghani_Ahmadzai
# 2024-10-14 00:18:04,649 - INFO - Processing Abdul_Ghani_Ghani
# 2024-10-14 00:18:06,664 - INFO - Processing Ghulam_Ghaus
# 2024-10-14 00:18:08,227 - INFO - Processing Ghulam_Muhammad_Ghobar
# 2024-10-14 00:18:09,754 - INFO - Processing Mohammad_Gul_(Helmand_Council)
# 2024-10-14 00:18:11,073 - INFO - Processing Sayed_Yousuf_Halim
# 2024-10-14 00:18:13,046 - INFO - Processing Rangina_Hamidi
# 2024-10-14 00:18:14,591 - INFO - Processing Sayed_Zafar_Hashemi
# 2024-10-14 00:18:16,965 - INFO - Processing Qutbuddin_Hilal
# 2024-10-14 00:18:19,268 - INFO - Processing Mahboba_Hoqomal
# 2024-10-14 00:18:20,617 - INFO - Processing Musa_Hotak
# 2024-10-14 00:18:21,951 - INFO - Processing Mirza_Muhammad_Ismail
# 2024-10-14 00:18:23,584 - INFO - Processing Sayed_Jalal
# 2024-10-14 00:18:25,007 - INFO - Processing Said_Tayeb_Jawad
# 2024-10-14 00:18:26,565 - INFO - Processing Sayed_Jalal_Karim
# 2024-10-14 00:18:27,941 - INFO - Processing Hafizullah_Shabaz_Khail
# 2024-10-14 00:18:29,384 - INFO - Processing Masoud_Khalili
# 2024-10-14 00:18:31,115 - INFO - Processing Mohammad_Khan_(athlete)
# 2024-10-14 00:18:32,802 - INFO - Processing Samoud_Khan
# 2024-10-14 00:18:34,549 - INFO - Processing Baran_Khan_Kudezai
# 2024-10-14 00:18:36,120 - INFO - Processing Azizullah_Lodin
# 2024-10-14 00:18:37,563 - INFO - Processing Razaq_Mamoon
# 2024-10-14 00:18:38,881 - INFO - Processing Fazel_Ahmed_Manawi
# 2024-10-14 00:18:40,180 - INFO - Processing Moeen_Marastial
# 2024-10-14 00:18:41,712 - INFO - Processing Ahmad_Wali_Massoud
# 2024-10-14 00:18:43,445 - INFO - Processing Mohammad_Daud_Miraki
# 2024-10-14 00:18:44,731 - INFO - Processing Abdul_Sattar_Mirzakwal
# 2024-10-14 00:18:46,123 - INFO - Processing Abdul_Karim_Misaq
# 2024-10-14 00:18:47,398 - INFO - Processing Ali_Mohammad_(politician)
# 2024-10-14 00:18:48,853 - INFO - Processing Nasruddin_Mohseni
# 2024-10-14 00:18:50,204 - INFO - Processing Davood_Moradian
# 2024-10-14 00:18:51,605 - INFO - Processing Zalmai_Mujadidi
# 2024-10-14 00:18:53,120 - INFO - Processing Sardar_Mohammad_Nadir_Naeem
# 2024-10-14 00:18:54,507 - INFO - Processing Daoud_Naji
# 2024-10-14 00:18:56,074 - INFO - Processing Gholam_Rabani_Nasher
# 2024-10-14 00:18:57,384 - INFO - Processing Ghulam_Faroq_Nijrabi
# 2024-10-14 00:18:59,057 - INFO - Processing Zabih-U-llah_Ghazi_Noristani
# 2024-10-14 00:19:00,791 - INFO - Processing Mohammed_Tahir_Omar
# 2024-10-14 00:19:02,084 - INFO - Processing Mohammed_Qalamuddin
# 2024-10-14 00:19:04,301 - INFO - Processing Ghulam_Mohammad_Rigi
# 2024-10-14 00:19:05,672 - INFO - Processing Ghulam_Hassan_Safi
# 2024-10-14 00:19:07,383 - INFO - Processing Hanifa_Safi
# 2024-10-14 00:19:08,647 - INFO - Processing Mohammed_Zia_Salehi
# 2024-10-14 00:19:10,240 - INFO - Processing Abdul_Majid_Samim
# 2024-10-14 00:19:11,714 - INFO - Processing Saber_Sangar
# 2024-10-14 00:19:13,192 - INFO - Processing Sayed_Nasim_Mihanparast
# 2024-10-14 00:19:14,628 - INFO - Processing Suhail_Shaheen
# 2024-10-14 00:19:16,153 - INFO - Processing Fazal_Hadi_Shinwari
# 2024-10-14 00:19:17,721 - INFO - Processing Baktash_Siawash
# 2024-10-14 00:19:19,281 - INFO - Processing Hasan_Ali_Sultani
# 2024-10-14 00:19:20,694 - INFO - Processing Mohammad_Hashem_Taufiqui
# 2024-10-14 00:19:22,180 - INFO - Processing Pacha_Gul_Wafadar
# 2024-10-14 00:19:24,407 - INFO - Processing Wahidullah_Waissi
# 2024-10-14 00:19:26,051 - INFO - Processing Ahmadullah_Wasiq
# 2024-10-14 00:19:27,787 - INFO - Processing Gul_Ahmmad_Yama
# 2024-10-14 00:19:29,423 - INFO - Processing Abdul_Salam_Zaeef
# 2024-10-14 00:19:31,492 - INFO - Processing Abdul_Zahir_(Konar_Education_Minister)
# 2024-10-14 00:19:33,791 - INFO - Processing Mohammed_Zaman
# 2024-10-14 00:19:35,524 - INFO - Processing Ziauddin_(Afghan_militia_leader)
# 2024-10-14 00:19:37,244 - INFO - Processing Qari_Ziauddin
# 2024-10-14 00:19:40,193 - INFO - Processing Abdul_Ghafor_Zori
# 2024-10-14 00:19:41,609 - INFO - Processing Ali_Pasha_of_Gusinje
# 2024-10-14 00:19:43,090 - INFO - Processing Ylli_Asllani
# 2024-10-14 00:19:44,432 - INFO - Processing Azis_Tahir_Ajdonati
# 2024-10-14 00:19:45,848 - INFO - Processing Bislim_Bajgora
# 2024-10-14 00:19:47,359 - INFO - Processing Kastriot_Berissa
# 2024-10-14 00:19:48,691 - INFO - Processing Bardhok_Biba
# 2024-10-14 00:19:50,539 - INFO - Processing Kostandin_Boshnjaku
# 2024-10-14 00:19:52,055 - INFO - Processing Spartak_Braho
# 2024-10-14 00:19:53,401 - INFO - Processing Safet_Butka
# 2024-10-14 00:19:54,835 - INFO - Processing Uran_Butka
# 2024-10-14 00:19:56,243 - INFO - Processing Refo_Çapari
# 2024-10-14 00:19:57,532 - INFO - Processing Neritan_Ceka
# 2024-10-14 00:19:58,869 - INFO - Processing Hysni_Curri
# 2024-10-14 00:20:00,394 - INFO - Processing Ibrahim_Dalliu
# 2024-10-14 00:20:01,930 - INFO - Processing Niazi_Demi
# 2024-10-14 00:20:03,222 - INFO - Processing Abdurrahman_Dibra
# 2024-10-14 00:20:05,173 - INFO - Processing Bujar_Dida
# 2024-10-14 00:20:06,659 - INFO - Processing Ahmed_Dino
# 2024-10-14 00:20:08,349 - INFO - Processing Rasih_Dino
# 2024-10-14 00:20:10,167 - INFO - Processing Ferhat_Bey_Draga
# 2024-10-14 00:20:11,652 - INFO - Processing Nexhip_Draga
# 2024-10-14 00:20:13,155 - INFO - Processing Aqif_Pasha_Elbasani
# 2024-10-14 00:20:14,876 - INFO - Processing Abas_Ermenji
# 2024-10-14 00:20:16,281 - INFO - Processing Qamil_Musa_Haxhi_Feza
# 2024-10-14 00:20:18,972 - INFO - Processing Themistokli_Gërmenji
# 2024-10-14 00:20:20,821 - INFO - Processing Sabri_Godo
# 2024-10-14 00:20:22,661 - INFO - Processing Mihal_Grameno
# 2024-10-14 00:20:24,068 - INFO - Processing Aćif_Hadžiahmetović
# 2024-10-14 00:20:25,657 - INFO - Processing High_Council_of_Regency
# 2024-10-14 00:20:27,151 - INFO - Processing Kurt_Agë_Kadiu
# 2024-10-14 00:20:28,471 - INFO - Processing Mehmed_Kalakula
# 2024-10-14 00:20:29,788 - INFO - Processing Alfred_Karamuço
# 2024-10-14 00:20:31,162 - INFO - Processing Ibrahim_Karbunara
# 2024-10-14 00:20:33,324 - INFO - Processing Ali_Këlcyra
# 2024-10-14 00:20:34,873 - INFO - Processing Bajram_Kelmendi
# 2024-10-14 00:20:36,250 - INFO - Processing Kristo_Kirka
# 2024-10-14 00:20:37,676 - INFO - Processing Elez_Koçi
# 2024-10-14 00:20:39,292 - INFO - Processing Xhelal_Koprëncka
# 2024-10-14 00:20:41,146 - INFO - Processing Kryeziu_family
# 2024-10-14 00:20:42,872 - INFO - Processing Artur_Kuko
# 2024-10-14 00:20:44,248 - INFO - Processing Xhavid_Leskoviku
# 2024-10-14 00:20:45,574 - INFO - Processing Sabit_Lulo
# 2024-10-14 00:20:46,989 - INFO - Processing Gjon_Markagjoni
# 2024-10-14 00:20:48,354 - INFO - Processing Tefik_Mborja
# 2024-10-14 00:20:50,107 - INFO - Processing Hysni_Milloshi
# 2024-10-14 00:20:51,756 - INFO - Processing Musa_Qazimi
# 2024-10-14 00:20:53,234 - INFO - Processing Mustafa_Ndroqi
# 2024-10-14 00:20:54,628 - INFO - Processing Behxhet_Nepravishta
# 2024-10-14 00:20:55,914 - INFO - Processing Adrian_Neritani
# 2024-10-14 00:20:57,615 - INFO - Processing Sali_Nivica
# 2024-10-14 00:20:59,049 - INFO - Processing Thoma_Orologa
# 2024-10-14 00:21:00,526 - INFO - Processing Bedri_Pejani
# 2024-10-14 00:21:02,161 - INFO - Processing Kadri_Prishtina
# 2024-10-14 00:21:03,569 - INFO - Processing Ymer_Prizreni
# 2024-10-14 00:21:04,891 - INFO - Processing Avni_Rustemi
# 2024-10-14 00:21:06,193 - INFO - Processing Chatin_Sarachi
# 2024-10-14 00:21:08,040 - INFO - Processing Nebi_Sefa
# 2024-10-14 00:21:10,618 - INFO - Processing Eduard_Shalsi
# 2024-10-14 00:21:11,983 - INFO - Processing Ylli_Vesel_Shehu
# 2024-10-14 00:21:13,307 - INFO - Processing Athanas_Shundi
# 2024-10-14 00:21:14,693 - INFO - Processing Xhelal_Sveçla
# 2024-10-14 00:21:16,418 - INFO - Processing Mehmet_Tahsini
# 2024-10-14 00:21:17,757 - INFO - Processing Ibrahim_Temo
# 2024-10-14 00:21:19,184 - INFO - Processing Afrim_Tole
# 2024-10-14 00:21:20,513 - INFO - Processing Syreja_Vlora
# 2024-10-14 00:21:22,006 - INFO - Processing Visarion_Xhuvani
# 2024-10-14 00:21:23,653 - INFO - Processing Visar_Ymeri
# 2024-10-14 00:21:25,077 - INFO - Processing Abdyl_Ypi
# 2024-10-14 00:21:26,442 - INFO - Processing Xhezair_Zaganjori
# 2024-10-14 00:21:27,819 - INFO - Processing Menduh_Zavalani
# 2024-10-14 00:21:29,546 - INFO - Processing Abdelkader_Zoukh
# 2024-10-14 00:21:30,917 - INFO - Processing Chaâbane_Aït_Abderrahim
# 2024-10-14 00:21:32,290 - INFO - Processing Ali_Aoun
# 2024-10-14 00:21:34,081 - INFO - Processing Basma_Azouar
# 2024-10-14 00:21:35,344 - INFO - Processing Mohamed_Seghir_Babes
# 2024-10-14 00:21:36,690 - INFO - Processing Noureddine_Bahbouh
# 2024-10-14 00:21:38,247 - INFO - Processing Lamine_Bechichi
# 2024-10-14 00:21:39,639 - INFO - Processing Aïssa_Bekkai
# 2024-10-14 00:21:41,083 - INFO - Processing Abdelhakim_Belabed
# 2024-10-14 00:21:42,930 - INFO - Processing Mohamed_Tarek_Belaribi
# 2024-10-14 00:21:44,430 - INFO - Processing Kamel_Beldjoud
# 2024-10-14 00:21:46,097 - INFO - Processing Aboubakr_Belkaid
# 2024-10-14 00:21:47,441 - INFO - Processing Youcef_Belmehdi
# 2024-10-14 00:21:48,747 - INFO - Processing Mohamed_Cherif_Belmihoub
# 2024-10-14 00:21:50,125 - INFO - Processing Mohamed_Belouizdad
# 2024-10-14 00:21:51,536 - INFO - Processing Benaouda_Hadj_Hacène_Bachterzi
# 2024-10-14 00:21:53,002 - INFO - Processing Souad_Bendjaballah
# 2024-10-14 00:21:54,337 - INFO - Processing Abdelkrim_Benmbarek
# 2024-10-14 00:21:55,766 - INFO - Processing Mohamed_Bensalam
# 2024-10-14 00:21:57,301 - INFO - Processing Fayçal_Bentaleb
# 2024-10-14 00:21:58,606 - INFO - Processing Ahmed_Bidani
# 2024-10-14 00:22:00,323 - INFO - Processing Kamel_Bidari
# 2024-10-14 00:22:01,773 - INFO - Processing Rachid_Bladehane
# 2024-10-14 00:22:03,553 - INFO - Processing Saïd_Boualam
# 2024-10-14 00:22:04,882 - INFO - Processing Rabah_Bouaziz
# 2024-10-14 00:22:06,707 - INFO - Processing Abdeslam_Bouchouareb
# 2024-10-14 00:22:08,093 - INFO - Processing Ibrahim_Boughali
# 2024-10-14 00:22:09,742 - INFO - Processing Yahia_Boukhari
# 2024-10-14 00:22:11,732 - INFO - Processing Mohamed_Bouslimani
# 2024-10-14 00:22:13,116 - INFO - Processing Foued_Chehat
# 2024-10-14 00:22:14,389 - INFO - Processing Hamza_Al_Sid_Cheikh
# 2024-10-14 00:22:15,732 - INFO - Processing Hocine_Cherhabil
# 2024-10-14 00:22:17,150 - INFO - Processing Abderrahmane_Meziane_Chérif
# 2024-10-14 00:22:18,525 - INFO - Processing Saïd_Chibane
# 2024-10-14 00:22:20,565 - INFO - Processing Brahim_Chibout
# 2024-10-14 00:22:21,867 - INFO - Processing Youcef_Chorfa
# 2024-10-14 00:22:23,368 - INFO - Processing Fazia_Dahleb
# 2024-10-14 00:22:24,970 - INFO - Processing Taha_Derbal
# 2024-10-14 00:22:26,401 - INFO - Processing Nassim_Diafat
# 2024-10-14 00:22:27,721 - INFO - Processing Mokhtar_Didouche
# 2024-10-14 00:22:29,217 - INFO - Processing Bouras_Djamel
# 2024-10-14 00:22:30,587 - INFO - Processing Fatiha_Serour
# 2024-10-14 00:22:31,954 - INFO - Processing Ahmed_Hamiani
# 2024-10-14 00:22:33,637 - INFO - Processing Nadir_Kassab
# 2024-10-14 00:22:35,477 - INFO - Processing Brahim_Djamel_Kassali
# 2024-10-14 00:22:36,924 - INFO - Processing Kaoutar_Krikou
# 2024-10-14 00:22:38,468 - INFO - Processing Sassi_Lamouri
# 2024-10-14 00:22:40,320 - INFO - Processing Mohamed_Maghlaoui
# 2024-10-14 00:22:41,778 - INFO - Processing Amar_Makhloufi
# 2024-10-14 00:22:43,522 - INFO - Processing Yassine_Merabi
# 2024-10-14 00:22:45,476 - INFO - Processing Brahim_Merad
# 2024-10-14 00:22:47,361 - INFO - Processing Bachir_Messaitfa
# 2024-10-14 00:22:48,814 - INFO - Processing Azzedine_Mihoubi
# 2024-10-14 00:22:50,539 - INFO - Processing Mohamed_Ali_Boughazi
# 2024-10-14 00:22:52,022 - INFO - Processing Amar_Mohammedi
# 2024-10-14 00:22:53,411 - INFO - Processing Samia_Moualfi
# 2024-10-14 00:22:54,962 - INFO - Processing Soraya_Mouloudji
# 2024-10-14 00:22:56,238 - INFO - Processing Yacine_Oualid
# 2024-10-14 00:22:57,657 - INFO - Processing Cherif_Rahmani
# 2024-10-14 00:22:59,267 - INFO - Processing Lakhdar_Rakhroukh
# 2024-10-14 00:23:00,555 - INFO - Processing Laid_Rebiga
# 2024-10-14 00:23:02,176 - INFO - Processing Kamel_Rezig
# 2024-10-14 00:23:03,771 - INFO - Processing Salim_Saadi
# 2024-10-14 00:23:05,260 - INFO - Processing Abdelhak_Saihi
# 2024-10-14 00:23:06,680 - INFO - Processing Hichem_Sofiane_Salaouatchi
# 2024-10-14 00:23:07,990 - INFO - Processing Naima_Salhi
# 2024-10-14 00:23:09,636 - INFO - Processing Abderezak_Sebgag
# 2024-10-14 00:23:11,010 - INFO - Processing Abderrachid_Tabbi
# 2024-10-14 00:23:12,338 - INFO - Processing Karim_Bibi_Triki
# 2024-10-14 00:23:13,760 - INFO - Processing Layachi_Yaker
# 2024-10-14 00:23:15,531 - INFO - Processing Ahmed_Zeghdar
# 2024-10-14 00:23:16,898 - INFO - Processing Adão_Francisco_Correia_de_Almeida
# 2024-10-14 00:23:18,248 - INFO - Processing Ana_Paula_Chantre_Luna_de_Carvalho
# 2024-10-14 00:23:19,954 - INFO - Processing Alexandre_Sebastião_André
# 2024-10-14 00:23:21,185 - INFO - Processing Paulino_Baptista
# 2024-10-14 00:23:22,677 - INFO - Processing Bernarda_Gonçalves_Martins
# 2024-10-14 00:23:24,075 - INFO - Processing João_Baptista_Borges
# 2024-10-14 00:23:25,542 - INFO - Processing Carolina_Cerqueira
# 2024-10-14 00:23:26,906 - INFO - Processing Arlete_Chimbinda
# 2024-10-14 00:23:28,275 - INFO - Processing Kafundanga_Chingunji
# 2024-10-14 00:23:29,677 - INFO - Processing Jeremias_Chitunda
# 2024-10-14 00:23:31,001 - INFO - Processing Abel_Chivukuvuku
# 2024-10-14 00:23:32,381 - INFO - Processing Fiel_Domingos_Constantino
# 2024-10-14 00:23:34,358 - INFO - Processing Adalberto_Costa_Júnior
# 2024-10-14 00:23:37,146 - INFO - Processing Adjany_Costa
# 2024-10-14 00:23:38,534 - INFO - Processing Álvaro_Arnaldo_Craveiro
# 2024-10-14 00:23:39,882 - INFO - Processing Raul_Danda
# 2024-10-14 00:23:41,367 - INFO - Processing Diamantino_Pedro_Azevedo
# 2024-10-14 00:23:42,738 - INFO - Processing Faustina_Fernandes_Inglês_de_Almeida_Alves
# 2024-10-14 00:23:44,023 - INFO - Processing Abraão_Gourgel
# 2024-10-14 00:23:45,403 - INFO - Processing Jofre_Van-Dúnem_Júnior
# 2024-10-14 00:23:46,751 - INFO - Processing José_Carvalho_da_Rocha
# 2024-10-14 00:23:48,007 - INFO - Processing José_Luis_de_Matos
# 2024-10-14 00:23:49,427 - INFO - Processing Kambamba_Kulaxingo
# 2024-10-14 00:23:51,048 - INFO - Processing Jesus_Faria_Maiato
# 2024-10-14 00:23:52,321 - INFO - Processing Manuel_Neto_da_Costa
# 2024-10-14 00:23:53,634 - INFO - Processing Manuel_Tavares_de_Almeida
# 2024-10-14 00:23:55,607 - INFO - Processing Marcos_Alexandre_Nhunga
# 2024-10-14 00:23:56,963 - INFO - Processing Maria_Cândida_Pereira_Teixeira
# 2024-10-14 00:23:58,570 - INFO - Processing Maria_do_Rosário_Teixeira_de_Alva_Sequeira_Bragança_Sambo
# 2024-10-14 00:24:02,362 - INFO - Processing David_Mendes
# 2024-10-14 00:24:03,718 - INFO - Processing Saíde_Mingas
# 2024-10-14 00:24:06,964 - INFO - Processing Fernando_Faustino_Muteka
# 2024-10-14 00:24:08,406 - INFO - Processing Pedro_Mutinde
# 2024-10-14 00:24:09,713 - INFO - Processing José_Ndele
# 2024-10-14 00:24:11,105 - INFO - Processing Ana_Paula_Sacramento_Neto
# 2024-10-14 00:24:12,568 - INFO - Processing Daniel_Ntongi-Nzinga
# 2024-10-14 00:24:13,948 - INFO - Processing Paula_Cristina_Francisco_Coelho
# 2024-10-14 00:24:15,711 - INFO - Processing Pedro_Pedalé
# 2024-10-14 00:24:17,116 - INFO - Processing Elias_Salupeto_Pena
# 2024-10-14 00:24:18,774 - INFO - Processing Johnny_Eduardo_Pinnock
# 2024-10-14 00:24:20,828 - INFO - Processing Santana_André_Pitra
# 2024-10-14 00:24:22,300 - INFO - Processing Francisco_Manuel_Monteiro_de_Queiróz
# 2024-10-14 00:24:23,676 - INFO - Processing José_Aníbal_Lopes_Rocha
# 2024-10-14 00:24:25,550 - INFO - Processing José_da_Rocha
# 2024-10-14 00:24:27,097 - INFO - Processing Rosa_Luís_de_Sousa_Micolo
# 2024-10-14 00:24:28,401 - INFO - Processing Luís_Gomes_Sambo
# 2024-10-14 00:24:29,913 - INFO - Processing Branca_Manuel_Espirito_Santo
# 2024-10-14 00:24:31,379 - INFO - Processing João_Ernesto_dos_Santos
# 2024-10-14 00:24:33,069 - INFO - Processing José_Filomeno_dos_Santos
# 2024-10-14 00:24:34,422 - INFO - Processing Jonas_Savimbi
# 2024-10-14 00:24:36,059 - INFO - Processing Pinda_Simão
# 2024-10-14 00:24:37,369 - INFO - Processing Manuel_Bernardo_de_Sousa
# 2024-10-14 00:24:38,888 - INFO - Processing Augusto_da_Silva_Tomás
# 2024-10-14 00:24:40,190 - INFO - Processing José_Jacinto_Van-Dúnem
# 2024-10-14 00:24:41,790 - INFO - Processing José_Vieira_Dias_Van-Dúnem
# 2024-10-14 00:24:43,319 - INFO - Processing Luzia_Inglês_Van-Dúnem
# 2024-10-14 00:24:45,262 - INFO - Processing Manuel_Vicente
# 2024-10-14 00:24:47,167 - INFO - Processing Mfulupinga_Nlando_Victor
# 2024-10-14 00:24:49,580 - INFO - Processing Clement_Antonio
# 2024-10-14 00:24:50,951 - INFO - Processing Randolph_Beazer
# 2024-10-14 00:24:52,429 - INFO - Processing Studiation_Brown
# 2024-10-14 00:24:55,536 - INFO - Processing Alex_Browne_(politician)
# 2024-10-14 00:24:57,006 - INFO - Processing Colin_O'Neil_Browne
# 2024-10-14 00:24:58,285 - INFO - Processing James_Carlisle
# 2024-10-14 00:24:59,679 - INFO - Processing Gail_Christian
# 2024-10-14 00:25:01,150 - INFO - Processing Mackenzie_Frank
# 2024-10-14 00:25:02,682 - INFO - Processing Osbert_Richard_Frederick
# 2024-10-14 00:25:04,452 - INFO - Processing Caleb_Gardiner
# 2024-10-14 00:25:06,316 - INFO - Processing Shenella_Mary_Shadida_Govia
# 2024-10-14 00:25:07,878 - INFO - Processing William_Haynes-Smith
# 2024-10-14 00:25:09,565 - INFO - Processing Tim_Hector
# 2024-10-14 00:25:10,988 - INFO - Processing Cheryl_Mary_Clare_Hurst
# 2024-10-14 00:25:12,349 - INFO - Processing Wilfred_Jacobs
# 2024-10-14 00:25:13,902 - INFO - Processing Rick_James_(actor)
# 2024-10-14 00:25:16,138 - INFO - Processing Kiz_Johnson
# 2024-10-14 00:25:17,641 - INFO - Processing Fabian_Jones
# 2024-10-14 00:25:19,242 - INFO - Processing Johnathan_Joseph_(politician)
# 2024-10-14 00:25:20,825 - INFO - Processing Kelvin_Simon
# 2024-10-14 00:25:22,230 - INFO - Processing Harold_Lovell
# 2024-10-14 00:25:23,909 - INFO - Processing Edmond_Mansoor
# 2024-10-14 00:25:25,620 - INFO - Processing David_Massiah
# 2024-10-14 00:25:27,362 - INFO - Processing Joanne_Massiah
# 2024-10-14 00:25:28,630 - INFO - Processing Dwayne_George
# 2024-10-14 00:25:30,052 - INFO - Processing Knacyntar_Nedd
# 2024-10-14 00:25:31,367 - INFO - Processing Melford_Nicholas
# 2024-10-14 00:25:32,665 - INFO - Processing Shawn_Nicholas
# 2024-10-14 00:25:34,021 - INFO - Processing Bernard_Percival
# 2024-10-14 00:25:35,388 - INFO - Processing Jamale_Pringle
# 2024-10-14 00:25:36,846 - INFO - Processing Philip_Shoul
# 2024-10-14 00:25:38,409 - INFO - Processing Rawdon_Turner
# 2024-10-14 00:25:39,791 - INFO - Processing Alincia_Williams-Grant
# 2024-10-14 00:25:41,312 - INFO - Processing Juan_Alemann
# 2024-10-14 00:25:42,833 - INFO - Processing Germán_Alfaro
# 2024-10-14 00:25:44,264 - INFO - Processing Joaquín_Samuel_de_Anchorena
# 2024-10-14 00:25:45,981 - INFO - Processing Juan_Agustín_Augier
# 2024-10-14 00:25:47,598 - INFO - Processing Uladislao_Augier
# 2024-10-14 00:25:49,282 - INFO - Processing Marco_Aurelio_Avellaneda
# 2024-10-14 00:25:51,532 - INFO - Processing Joaquín_Belgrano
# 2024-10-14 00:25:52,930 - INFO - Processing Antonio_Bermejo
# 2024-10-14 00:25:54,243 - INFO - Processing Antonio_Beruti
# 2024-10-14 00:25:56,224 - INFO - Processing Héctor_Bidonde
# 2024-10-14 00:25:57,662 - INFO - Processing Silvano_Bores
# 2024-10-14 00:25:59,651 - INFO - Processing Exequiel_Bustillo
# 2024-10-14 00:26:01,094 - INFO - Processing Mario_Cafiero
# 2024-10-14 00:26:02,620 - INFO - Processing Alberto_Manuel_Campos
# 2024-10-14 00:26:04,017 - INFO - Processing Alejo_Castex
# 2024-10-14 00:26:06,220 - INFO - Processing Dámaso_Centeno
# 2024-10-14 00:26:07,711 - INFO - Processing Rossana_Chahla
# 2024-10-14 00:26:09,477 - INFO - Processing Lázaro_Chiappe
# 2024-10-14 00:26:10,968 - INFO - Processing Carlos_Corach
# 2024-10-14 00:26:12,535 - INFO - Processing Jorge_Coscia
# 2024-10-14 00:26:13,982 - INFO - Processing Carlos_de_la_Rosa
# 2024-10-14 00:26:15,521 - INFO - Processing Juan_Carlos_Del_Bello
# 2024-10-14 00:26:18,295 - INFO - Processing Luis_L._Domínguez
# 2024-10-14 00:26:19,764 - INFO - Processing Máximo_Etchecopar
# 2024-10-14 00:26:21,124 - INFO - Processing Héctor_Toty_Flores
# 2024-10-14 00:26:22,684 - INFO - Processing Guillermo_Francos
# 2024-10-14 00:26:24,297 - INFO - Processing Juan_Fugl
# 2024-10-14 00:26:25,625 - INFO - Processing Santiago_Gallo
# 2024-10-14 00:26:27,370 - INFO - Processing Manuel_José_García
# 2024-10-14 00:26:28,710 - INFO - Processing Juan_José_Gómez_Centurión
# 2024-10-14 00:26:30,327 - INFO - Processing Luis_Carlos_Gómez_Centurión
# 2024-10-14 00:26:31,620 - INFO - Processing Martín_Guzmán
# 2024-10-14 00:26:33,417 - INFO - Processing Federico_Helguera
# 2024-10-14 00:26:35,064 - INFO - Processing Fernando_Iglesias_(Argentine_politician)
# 2024-10-14 00:26:36,530 - INFO - Processing Ricardo_Kennedy
# 2024-10-14 00:26:37,862 - INFO - Processing Carlos_Kunkel
# 2024-10-14 00:26:39,201 - INFO - Processing Norberto_La_Porta
# 2024-10-14 00:26:40,574 - INFO - Processing Andrés_Larroque
# 2024-10-14 00:26:42,219 - INFO - Processing Julián_de_Leyva
# 2024-10-14 00:26:43,624 - INFO - Processing Mónica_López_(politician)
# 2024-10-14 00:26:45,317 - INFO - Processing Lucio_Victorio_Mansilla
# 2024-10-14 00:26:47,145 - INFO - Processing Nicolás_Massot
# 2024-10-14 00:26:48,744 - INFO - Processing Martín_Menem
# 2024-10-14 00:26:50,217 - INFO - Processing Juan_Mignaburu
# 2024-10-14 00:26:52,525 - INFO - Processing Guillermo_Montenegro
# 2024-10-14 00:26:54,739 - INFO - Processing Mariano_Moreno
# 2024-10-14 00:26:56,953 - INFO - Processing Marcelo_Muniagurria
# 2024-10-14 00:26:58,483 - INFO - Processing Fernando_Nadra
# 2024-10-14 00:27:00,560 - INFO - Processing Rómulo_Sebastián_Naón
# 2024-10-14 00:27:02,218 - INFO - Processing Santiago_G._O'Farrell
# 2024-10-14 00:27:03,760 - INFO - Processing Alfredo_Olmedo
# 2024-10-14 00:27:05,105 - INFO - Processing Miguel_Ángel_Pesce
# 2024-10-14 00:27:06,795 - INFO - Processing Carlos_Petroni
# 2024-10-14 00:27:08,736 - INFO - Processing Alejo_Peyret
# 2024-10-14 00:27:10,395 - INFO - Processing Aldo_Pignanelli
# 2024-10-14 00:27:11,779 - INFO - Processing Abel_Posse
# 2024-10-14 00:27:14,267 - INFO - Processing Enrique_S._Quintana
# 2024-10-14 00:27:15,989 - INFO - Processing Amán_Rawson
# 2024-10-14 00:27:17,397 - INFO - Processing Martín_Sabbatella
# 2024-10-14 00:27:19,101 - INFO - Processing Juan_Pablo_Schiavi
# 2024-10-14 00:27:20,785 - INFO - Processing Héctor_Tizón
# 2024-10-14 00:27:22,339 - INFO - Processing Claudio_Uberti
# 2024-10-14 00:27:23,954 - INFO - Processing Arístides_Villanueva
# 2024-10-14 00:27:25,762 - INFO - Processing Jorge_Yoma
# 2024-10-14 00:27:27,698 - INFO - Processing Ashot_Arsenyan
# 2024-10-14 00:27:29,461 - INFO - Processing Vigen_Chitechyan
# 2024-10-14 00:27:31,008 - INFO - Processing Hayk_Chobanyan
# 2024-10-14 00:27:32,902 - INFO - Processing Gurgen_Egiazaryan
# 2024-10-14 00:27:34,367 - INFO - Processing Parunak_Ferukhan
# 2024-10-14 00:27:35,768 - INFO - Processing Gevorg_Ghazaryan_(politician)
# 2024-10-14 00:27:37,240 - INFO - Processing Andrias_Ghukasyan
# 2024-10-14 00:27:38,746 - INFO - Processing Aram_Grigoryan_(politician)
# 2024-10-14 00:27:40,272 - INFO - Processing Vahagn_Hovakimyan
# 2024-10-14 00:27:41,995 - INFO - Processing Tigran_Karapetyan
# 2024-10-14 00:27:43,341 - INFO - Processing Tigran_Khzmalyan
# 2024-10-14 00:27:44,889 - INFO - Processing Mikayel_Kotanyan
# 2024-10-14 00:27:46,295 - INFO - Processing Hrant_Maloyan
# 2024-10-14 00:27:47,775 - INFO - Processing Khachatur_Malumian
# 2024-10-14 00:27:49,393 - INFO - Processing Aram_Manukyan
# 2024-10-14 00:27:51,258 - INFO - Processing Gevorg_Melik-Karagyozyan
# 2024-10-14 00:27:52,987 - INFO - Processing Vahan_Minakhoryan
# 2024-10-14 00:27:54,441 - INFO - Processing Ruben_Miroyan
# 2024-10-14 00:27:56,039 - INFO - Processing Ruben_Mirzakhanyan
# 2024-10-14 00:27:57,597 - INFO - Processing Badal_Muradyan
# 2024-10-14 00:27:59,123 - INFO - Processing Narine_Tukhikyan
# 2024-10-14 00:28:01,550 - INFO - Processing Gabriel_Noradoungian
# 2024-10-14 00:28:03,273 - INFO - Processing Israel_Ori
# 2024-10-14 00:28:04,821 - INFO - Processing Paul_Paul
# 2024-10-14 00:28:06,262 - INFO - Processing Garo_Paylan
# 2024-10-14 00:28:08,027 - INFO - Processing Genrikh_Poghosyan
# 2024-10-14 00:28:09,503 - INFO - Processing Ishkhan_Saghatelyan
# 2024-10-14 00:28:11,223 - INFO - Processing Karen_Sargsyan_(sociologist)
# 2024-10-14 00:28:12,899 - INFO - Processing Martiros_Sarukhanyan
# 2024-10-14 00:28:14,411 - INFO - Processing Vartkes_Serengülian
# 2024-10-14 00:28:15,834 - INFO - Processing Suren_Shadunts
# 2024-10-14 00:28:18,149 - INFO - Processing Ohannes_Tchekidjian
# 2024-10-14 00:28:20,340 - INFO - Processing Hrayr_Tovmasyan
# 2024-10-14 00:28:23,412 - INFO - Processing Usub_Bek_Temuryan
# 2024-10-14 00:28:25,300 - INFO - Processing Kegham_Vanigian
# 2024-10-14 00:28:27,469 - INFO - Processing Serop_Zakaryan
# 2024-10-14 00:28:29,323 - INFO - Processing Alfons_Adam
# 2024-10-14 00:28:31,067 - INFO - Processing Ingo_Appelt
# 2024-10-14 00:28:34,109 - INFO - Processing Maximilian_Anton_Karl,_Count_Baillet_de_Latour
# 2024-10-14 00:28:36,175 - INFO - Processing Heinrich_Alfred_Barb
# 2024-10-14 00:28:37,899 - INFO - Processing Leopold_Berchtold
# 2024-10-14 00:28:40,060 - INFO - Processing Joseph_Buttinger
# 2024-10-14 00:28:42,445 - INFO - Processing Prince_Carl_of_Solms-Braunfels
# 2024-10-14 00:28:43,935 - INFO - Processing Count_Václav_Antonín_Chotek_of_Chotkov_and_Vojnín
# 2024-10-14 00:28:45,546 - INFO - Processing Citizens'_Ministry
# 2024-10-14 00:28:47,141 - INFO - Processing Richard_von_Coudenhove-Kalergi
# 2024-10-14 00:28:49,293 - INFO - Processing Franz_Dinghofer
# 2024-10-14 00:28:51,116 - INFO - Processing George_Abraham_von_Dyhrn
# 2024-10-14 00:28:52,992 - INFO - Processing Eduard_von_Grebmer_zu_Wolfsthurn
# 2024-10-14 00:28:54,891 - INFO - Processing Barbara_Eibinger-Miedl
# 2024-10-14 00:28:55,913 - INFO - Processing Hans_Ferlitsch
# 2024-10-14 00:28:57,781 - INFO - Processing Friedhelm_Frischenschlager
# 2024-10-14 00:28:59,582 - INFO - Processing Walter_Guggenberger
# 2024-10-14 00:29:04,048 - INFO - Processing Ulrich_Habsburg-Lothringen
# 2024-10-14 00:29:05,463 - INFO - Processing Ernst_Hampel_(politician)
# 2024-10-14 00:29:06,792 - INFO - Processing Hans_Peter_Haselsteiner
# 2024-10-14 00:29:08,147 - INFO - Processing Friedrich_Wilhelm_von_Haugwitz
# 2024-10-14 00:29:10,799 - INFO - Processing Eduard_Hedvicek
# 2024-10-14 00:29:15,351 - INFO - Processing Hermann_Stern
# 2024-10-14 00:29:16,934 - INFO - Processing Jürgen_Himmelbauer
# 2024-10-14 00:29:18,366 - INFO - Processing Anton_Hofer
# 2024-10-14 00:29:19,839 - INFO - Processing Andreas_Hörtnagl
# 2024-10-14 00:29:21,245 - INFO - Processing Franz_Jetzinger
# 2024-10-14 00:29:22,932 - INFO - Processing Konstantin_Jireček
# 2024-10-14 00:29:24,632 - INFO - Processing Hugo_Jury
# 2024-10-14 00:29:26,044 - INFO - Processing Joseph_Kenner
# 2024-10-14 00:29:27,526 - INFO - Processing Theodor_Kery
# 2024-10-14 00:29:29,172 - INFO - Processing Michael_Killisch-Horn
# 2024-10-14 00:29:30,486 - INFO - Processing Sophia_Kircher
# 2024-10-14 00:29:31,955 - INFO - Processing Hubert_Klausner
# 2024-10-14 00:29:33,434 - INFO - Processing Martin_Kocher
# 2024-10-14 00:29:34,953 - INFO - Processing Józef_Kożdoń
# 2024-10-14 00:29:36,597 - INFO - Processing Gottfried_von_Kühnelt-Leddihn
# 2024-10-14 00:29:38,078 - INFO - Processing Franz_Leitner_(politician)
# 2024-10-14 00:29:39,589 - INFO - Processing Elmar_Lichtenegger
# 2024-10-14 00:29:41,029 - INFO - Processing Julius_Lippert_(historian)
# 2024-10-14 00:29:42,391 - INFO - Processing Reinhold_Lopatka
# 2024-10-14 00:29:43,921 - INFO - Processing Karl_Lütgendorf
# 2024-10-14 00:29:45,793 - INFO - Processing Jürgen_Mandl
# 2024-10-14 00:29:47,413 - INFO - Processing Renate_Mann
# 2024-10-14 00:29:49,229 - INFO - Processing Ferdinand_Mannlicher
# 2024-10-14 00:29:50,711 - INFO - Processing Christoph_Matznetter
# 2024-10-14 00:29:52,225 - INFO - Processing Johann_Gregor_Memhardt
# 2024-10-14 00:29:54,435 - INFO - Processing Franz_Moroder
# 2024-10-14 00:29:55,912 - INFO - Processing Heinz_Nittel
# 2024-10-14 00:29:57,661 - INFO - Processing Heidemaria_Onodi
# 2024-10-14 00:29:59,058 - INFO - Processing Brigitta_Pallauf
# 2024-10-14 00:30:00,808 - INFO - Processing Wladimir_von_Pawlowski
# 2024-10-14 00:30:02,193 - INFO - Processing Johann_Anton_von_Pergen
# 2024-10-14 00:30:03,637 - INFO - Processing Gerhard_Pfanzelter
# 2024-10-14 00:30:04,926 - INFO - Processing Walter_Pfrimer
# 2024-10-14 00:30:06,319 - INFO - Processing Leopold_Poetsch
# 2024-10-14 00:30:07,769 - INFO - Processing Thomas_Prinzhorn
# 2024-10-14 00:30:09,116 - INFO - Processing Gregor_Razumovsky_(activist)
# 2024-10-14 00:30:11,020 - INFO - Processing Horst_Rosenkranz
# 2024-10-14 00:30:13,576 - INFO - Processing Emil_Sax
# 2024-10-14 00:30:15,853 - INFO - Processing Peter_Schieder
# 2024-10-14 00:30:17,271 - INFO - Processing Karl_Schmitzer
# 2024-10-14 00:30:18,888 - INFO - Processing Sonja_Zwazl
# 2024-10-14 00:30:20,269 - INFO - Processing Georg_Adam,_Prince_of_Starhemberg
# 2024-10-14 00:30:21,992 - INFO - Processing Gundaker_Thomas_Starhemberg
# 2024-10-14 00:30:23,280 - INFO - Processing Josef_Staribacher
# 2024-10-14 00:30:24,596 - INFO - Processing Peter_Strasser_(politician)
# 2024-10-14 00:30:26,771 - INFO - Processing Julius_Tandler
# 2024-10-14 00:30:28,110 - INFO - Processing Leopold,_Count_von_Thun_und_Hohenstein
# 2024-10-14 00:30:29,956 - INFO - Processing Karl_Freiherr_von_Vogelsang
# 2024-10-14 00:30:31,506 - INFO - Processing Anton_von_Winzor
# 2024-10-14 00:30:32,895 - INFO - Processing Gisela_Wurm
# 2024-10-14 00:30:34,261 - INFO - Processing Alexander_Zach
# 2024-10-14 00:30:35,939 - INFO - Processing Curt_Franz_Wenzel_Christoph_Erdmann_Graf_Zedtwitz_von_Moraván_und_Duppau
# 2024-10-14 00:30:37,310 - INFO - Processing Karl_von_Zinzendorf
# 2024-10-14 00:30:38,603 - INFO - Processing Muzamil_Abdullayev
# 2024-10-14 00:30:40,063 - INFO - Processing Leyla_Abdullayeva
# 2024-10-14 00:30:41,501 - INFO - Processing Elchin_Afandiyev
# 2024-10-14 00:30:43,414 - INFO - Processing Fazail_Agamali
# 2024-10-14 00:30:45,393 - INFO - Processing Aliabbas_Salahzade
# 2024-10-14 00:30:46,931 - INFO - Processing Enver_Alikhanov
# 2024-10-14 00:30:48,583 - INFO - Processing Tarlan_Aliyarbayov
# 2024-10-14 00:30:50,122 - INFO - Processing Dilara_Aliyeva
# 2024-10-14 00:30:51,666 - INFO - Processing Araz_Alizadeh
# 2024-10-14 00:30:53,611 - INFO - Processing Ali_Asadov
# 2024-10-14 00:30:54,978 - INFO - Processing Ashraf_Bey_Taghiyev
# 2024-10-14 00:30:58,136 - INFO - Processing Chimnaz_Aslanova
# 2024-10-14 00:30:59,632 - INFO - Processing Akram_Aylisli
# 2024-10-14 00:31:01,386 - INFO - Processing Sahil_Babayev
# 2024-10-14 00:31:03,374 - INFO - Processing Huseyngulu_Baghirov
# 2024-10-14 00:31:04,798 - INFO - Processing Bakhish_bey_Rustambeyov
# 2024-10-14 00:31:06,146 - INFO - Processing Alovsat_Bakhshiyev
# 2024-10-14 00:31:07,654 - INFO - Processing Mirgasim_Cheshmazer
# 2024-10-14 00:31:09,277 - INFO - Processing Vilayat_Eyvazov
# 2024-10-14 00:31:10,669 - INFO - Processing Abdurrahman_Fatalibeyli
# 2024-10-14 00:31:12,365 - INFO - Processing Fazail_Ibrahimli
# 2024-10-14 00:31:13,808 - INFO - Processing Afshan_Gadimbeyova
# 2024-10-14 00:31:15,255 - INFO - Processing Garib_Karimoğlu
# 2024-10-14 00:31:16,784 - INFO - Processing Gudrat_Gasanguliev
# 2024-10-14 00:31:18,213 - INFO - Processing Mehrali_Gasimov
# 2024-10-14 00:31:19,195 - INFO - Processing Solomon_Grobshtein
# 2024-10-14 00:31:20,870 - INFO - Processing Teymur_Guliyev
# 2024-10-14 00:31:22,296 - INFO - Processing Mammad_Gurbanov
# 2024-10-14 00:31:23,912 - INFO - Processing Musa_Hacigasimov
# 2024-10-14 00:31:25,269 - INFO - Processing Asaf_Hajiyev
# 2024-10-14 00:31:27,308 - INFO - Processing Haji_Molla_Ahmad_Nuruzade
# 2024-10-14 00:31:28,968 - INFO - Processing Farhad_Hajiyev
# 2024-10-14 00:31:30,992 - INFO - Processing Hasan_Majidov
# 2024-10-14 00:31:32,364 - INFO - Processing Hasan_Hasanli
# 2024-10-14 00:31:34,003 - INFO - Processing Jamil_Hasanli
# 2024-10-14 00:31:35,543 - INFO - Processing Ali_M._Hasanov
# 2024-10-14 00:31:37,132 - INFO - Processing Zakir_Hasanov
# 2024-10-14 00:31:38,496 - INFO - Processing Ali_Huseynli
# 2024-10-14 00:31:39,887 - INFO - Processing Alisahib_Huseynov
# 2024-10-14 00:31:41,328 - INFO - Processing Ali_Ibrahimov
# 2024-10-14 00:31:42,866 - INFO - Processing Irshad_Aliyev
# 2024-10-14 00:31:44,561 - INFO - Processing Mamed_Iskenderov
# 2024-10-14 00:31:45,982 - INFO - Processing Vidadi_Isgandarov
# 2024-10-14 00:31:47,680 - INFO - Processing Ajdar_Ismailov
# 2024-10-14 00:31:49,573 - INFO - Processing Saftar_Jafarov
# 2024-10-14 00:31:50,868 - INFO - Processing Jeyhun_Jalilov
# 2024-10-14 00:31:52,228 - INFO - Processing Arastun_Javadov
# 2024-10-14 00:31:53,524 - INFO - Processing Rovshan_Javadov
# 2024-10-14 00:31:55,460 - INFO - Processing Anar_Karimov
# 2024-10-14 00:31:57,370 - INFO - Processing Boris_Kevorkov
# 2024-10-14 00:31:59,763 - INFO - Processing Gurban_Khalilov
# 2024-10-14 00:32:01,155 - INFO - Processing Ahmad_Kordary
# 2024-10-14 00:32:02,523 - INFO - Processing Lutfali_bey_Behbudov
# 2024-10-14 00:32:04,272 - INFO - Processing Ilham_Madatov
# 2024-10-14 00:32:05,663 - INFO - Processing Makhmud_Mamed-Guliev
# 2024-10-14 00:32:07,150 - INFO - Processing Majnun_Mammadov
# 2024-10-14 00:32:08,735 - INFO - Processing Musa_Mammadov
# 2024-10-14 00:32:10,528 - INFO - Processing Ramin_Mammadov
# 2024-10-14 00:32:12,055 - INFO - Processing Elshad_Mirbashir_oghlu
# 2024-10-14 00:32:14,470 - INFO - Processing Tahir_Mirkishili
# 2024-10-14 00:32:16,001 - INFO - Processing Movsum_Samadov
# 2024-10-14 00:32:17,616 - INFO - Processing Fuad_Naghiyev
# 2024-10-14 00:32:19,321 - INFO - Processing Eldar_Namazov
# 2024-10-14 00:32:21,011 - INFO - Processing Namig_Nasrullayev
# 2024-10-14 00:32:22,936 - INFO - Processing Siyavush_Novruzov
# 2024-10-14 00:32:24,528 - INFO - Processing Zahid_Oruj
# 2024-10-14 00:32:26,094 - INFO - Processing Sadig_Rahimov
# 2024-10-14 00:32:27,676 - INFO - Processing Suleyman_Rahimov
# 2024-10-14 00:32:29,620 - INFO - Processing Huseyn_Rahmanov
# 2024-10-14 00:32:31,455 - INFO - Processing Rovshen_Rzayev
# 2024-10-14 00:32:32,954 - INFO - Processing Hasan_Seyidov
# 2024-10-14 00:32:34,329 - INFO - Processing Hasan_Seyidov_(scientist)
# 2024-10-14 00:32:35,790 - INFO - Processing Parviz_Shahbazov
# 2024-10-14 00:32:37,321 - INFO - Processing Mammad_agha_Shahtakhtinski
# 2024-10-14 00:32:38,932 - INFO - Processing Abid_Sharifov
# 2024-10-14 00:32:40,396 - INFO - Processing Shirali_Akhundov
# 2024-10-14 00:32:42,154 - INFO - Processing Ikhtiyar_Shirinov
# 2024-10-14 00:32:43,976 - INFO - Processing Bakhtiyar_Vahabzadeh
# 2024-10-14 00:32:45,458 - INFO - Processing Vugar_Mustafayev_(minister)
# 2024-10-14 00:32:47,631 - INFO - Processing Yusif_Ziya_Talibzadeh
# 2024-10-14 00:32:49,436 - INFO - Processing Nurali_Yusifbayli
# 2024-10-14 00:32:50,885 - INFO - Processing Keith_Bell_(Bahamian_politician)
# 2024-10-14 00:32:52,507 - INFO - Processing Charles_Carter_(Bahamian_journalist)
# 2024-10-14 00:32:53,818 - INFO - Processing Harold_Christie
# 2024-10-14 00:32:55,494 - INFO - Processing Timothy_Donaldson
# 2024-10-14 00:32:56,952 - INFO - Processing Eugene_Dupuch
# 2024-10-14 00:32:58,647 - INFO - Processing Joseph_Robert_Love
# 2024-10-14 00:33:00,243 - INFO - Processing McKell_Bonaby
# 2024-10-14 00:33:01,720 - INFO - Processing Pakesia_Parker-Edgecombe
# 2024-10-14 00:33:03,537 - INFO - Processing James_Carmichael_Smith_(postmaster)
# 2024-10-14 00:33:05,023 - INFO - Processing Mohammed_Isa_Al_Abbasi
# 2024-10-14 00:33:07,271 - INFO - Processing Abdulla_Adel_Fakhro
# 2024-10-14 00:33:08,992 - INFO - Processing Abdullah_bin_Isa_Al_Khalifa
# 2024-10-14 00:33:10,366 - INFO - Processing Ahmed_Behzad_(Bahrain)
# 2024-10-14 00:33:12,774 - INFO - Processing Kamal_Ahmed_(politician)
# 2024-10-14 00:33:14,383 - INFO - Processing Mohamed_Ali_Hasan_Ali
# 2024-10-14 00:33:15,895 - INFO - Processing Khalid_Almoayed
# 2024-10-14 00:33:17,804 - INFO - Processing Aymen_Tawfeeq_Almoayed
# 2024-10-14 00:33:19,426 - INFO - Processing Nazar_Al_Baharna
# 2024-10-14 00:33:20,767 - INFO - Processing Mahmood_Al_Bahrani
# 2024-10-14 00:33:22,154 - INFO - Processing Ammar_Al_Bannai
# 2024-10-14 00:33:23,810 - INFO - Processing Jawad_Fairooz
# 2024-10-14 00:33:25,171 - INFO - Processing Qasim_Fakhro
# 2024-10-14 00:33:26,744 - INFO - Processing Faisal_al-Hamar
# 2024-10-14 00:33:28,268 - INFO - Processing Nabeel_bin_Yaqub_Al-Hamar
# 2024-10-14 00:33:29,827 - INFO - Processing Isa_bin_Abdulrahman_Al_Hammadi
# 2024-10-14 00:33:31,599 - INFO - Processing Jameel_Humadan
# 2024-10-14 00:33:34,379 - INFO - Processing Isa_bin_Ibrahim_Al_Khalifa
# 2024-10-14 00:33:35,783 - INFO - Processing Fahmi_al-Jowder
# 2024-10-14 00:33:37,286 - INFO - Processing Saud_Kanoo
# 2024-10-14 00:33:38,900 - INFO - Processing Essam_Khalaf
# 2024-10-14 00:33:40,278 - INFO - Processing Abdullah_bin_Hamad_bin_Isa_Al_Khalifa
# 2024-10-14 00:33:41,751 - INFO - Processing Ahmed_bin_Mohamed_Al_Khalifa
# 2024-10-14 00:33:43,018 - INFO - Processing Ali_bin_Khalifa_Al_Khalifa
# 2024-10-14 00:33:44,414 - INFO - Processing Hala_bint_Mohammed_Al_Khalifa
# 2024-10-14 00:33:45,699 - INFO - Processing Ibrahim_ibn_Khalifa_Al_Khalifa
# 2024-10-14 00:33:46,980 - INFO - Processing Mai_bint_Mohammed_Al_Khalifa
# 2024-10-14 00:33:48,395 - INFO - Processing Salman_bin_Khalifa_Al_Khalifa
# 2024-10-14 00:33:49,676 - INFO - Processing Hamad_Al_Kooheji
# 2024-10-14 00:33:51,337 - INFO - Processing Abdullatif_Al-Mahmood
# 2024-10-14 00:33:52,728 - INFO - Processing Rasheed_Mohammed_Al_Maraj
# 2024-10-14 00:33:54,084 - INFO - Processing Khalid_Al_Maskati
# 2024-10-14 00:33:55,986 - INFO - Processing Abdulhussain_bin_Ali_Mirza
# 2024-10-14 00:33:57,316 - INFO - Processing Mohammed_Al-Buainain
# 2024-10-14 00:33:58,640 - INFO - Processing Mohammed_bin_Khalifa_bin_Ahmed
# 2024-10-14 00:34:00,036 - INFO - Processing Mohammed_bin_Khalifa_bin_Ali_Al_Khalifa
# 2024-10-14 00:34:01,424 - INFO - Processing Abdulrahman_al-Nuaimi
# 2024-10-14 00:34:02,696 - INFO - Processing Ammar_Qambar
# 2024-10-14 00:34:04,200 - INFO - Processing Isa_Qassim
# 2024-10-14 00:34:05,767 - INFO - Processing Abdulla_Hassan_Saif
# 2024-10-14 00:34:07,353 - INFO - Processing Ali_bin_Saleh_Al_Saleh
# 2024-10-14 00:34:08,636 - INFO - Processing Ahmed_Al-Salloum
# 2024-10-14 00:34:10,068 - INFO - Processing Salman_bin_Hamad_Al_Khalifa
# 2024-10-14 00:34:11,504 - INFO - Processing Abdul_Motaleb
# 2024-10-14 00:34:12,871 - INFO - Processing Abdus_Salam_(Chattogram_politician)
# 2024-10-14 00:34:14,200 - INFO - Processing Abul_Hashim
# 2024-10-14 00:34:15,654 - INFO - Processing Oli_Ahad
# 2024-10-14 00:34:17,103 - INFO - Processing Chowdhury_Shamsuddin_Ahmed
# 2024-10-14 00:34:18,586 - INFO - Processing Farid_Ahmed
# 2024-10-14 00:34:20,072 - INFO - Processing Muzaffar_Ahmed_(NAP_politician)
# 2024-10-14 00:34:21,481 - INFO - Processing AKM_Hafizuddin
# 2024-10-14 00:34:22,980 - INFO - Processing Mohammad_Manjur_Alam
# 2024-10-14 00:34:24,823 - INFO - Processing M_Hossain_Ali
# 2024-10-14 00:34:26,914 - INFO - Processing Aminul_Islam_Rabel
# 2024-10-14 00:34:28,243 - INFO - Processing Mohammad_A._Arafat
# 2024-10-14 00:34:29,683 - INFO - Processing Ashab_Uddin_Ahmad
# 2024-10-14 00:34:31,654 - INFO - Processing Shafiqur_Rahman_Badsha
# 2024-10-14 00:34:33,210 - INFO - Processing Selina_Banu
# 2024-10-14 00:34:34,623 - INFO - Processing Nurul_Huq_Bhuiyan
# 2024-10-14 00:34:36,434 - INFO - Processing Birendra_Kishore_Roaza
# 2024-10-14 00:34:37,781 - INFO - Processing Bishnu_Chattopadhyay
# 2024-10-14 00:34:39,354 - INFO - Processing AKM_Fazlul_Kabir_Chowdhury
# 2024-10-14 00:34:40,765 - INFO - Processing Aminul_Islam_Chowdhury
# 2024-10-14 00:34:42,454 - INFO - Processing Anwarul_Karim_Chowdhury
# 2024-10-14 00:34:43,884 - INFO - Processing Moinuddin_Ahmed_Chowdhury
# 2024-10-14 00:34:45,384 - INFO - Processing Sarwar_Jan_Chowdhury
# 2024-10-14 00:34:46,652 - INFO - Processing Shahinur_Pasha_Chowdhury
# 2024-10-14 00:34:48,815 - INFO - Processing Yusuf_Ali_Chowdhury
# 2024-10-14 00:34:50,495 - INFO - Processing Haji_Mohammad_Danesh
# 2024-10-14 00:34:51,874 - INFO - Processing Pulin_De
# 2024-10-14 00:34:53,338 - INFO - Processing James_Leo_Ferguson
# 2024-10-14 00:34:54,711 - INFO - Processing Abdul_Halim_Ghaznavi
# 2024-10-14 00:34:56,301 - INFO - Processing Debendra_Nath_Ghosh
# 2024-10-14 00:34:57,955 - INFO - Processing Ranesh_Das_Gupta
# 2024-10-14 00:34:59,449 - INFO - Processing AKM_Fazlul_Haque_(Jatiya_Party_politician)
# 2024-10-14 00:35:01,110 - INFO - Processing Syed_Najmuddin_Hashim
# 2024-10-14 00:35:02,630 - INFO - Processing M._Anwar_Hossain
# 2024-10-14 00:35:04,284 - INFO - Processing Nozir_Hossain
# 2024-10-14 00:35:05,879 - INFO - Processing Husam_Uddin_Chowdhury_Fultali
# 2024-10-14 00:35:07,465 - INFO - Processing Syed_Muhammad_Ibrahim
# 2024-10-14 00:35:08,909 - INFO - Processing Abul_Kashem
# 2024-10-14 00:35:10,384 - INFO - Processing Abul_Kashem_Khan
# 2024-10-14 00:35:11,964 - INFO - Processing Hatem_Ali_Khan
# 2024-10-14 00:35:13,284 - INFO - Processing Muhammad_Hamidullah_Khan
# 2024-10-14 00:35:14,836 - INFO - Processing Yar_Mohammad_Khan
# 2024-10-14 00:35:16,372 - INFO - Processing Kazi_Abdus_Shahid_Lal
# 2024-10-14 00:35:17,796 - INFO - Processing Jyotirindra_Bodhipriya_Larma
# 2024-10-14 00:35:19,444 - INFO - Processing Shamima_Harun_Lubna
# 2024-10-14 00:35:20,720 - INFO - Processing Manik_Lal_Ray
# 2024-10-14 00:35:22,010 - INFO - Processing Manjurul_Imam
# 2024-10-14 00:35:23,367 - INFO - Processing Mushrefa_Mishu
# 2024-10-14 00:35:24,677 - INFO - Processing Moin_Uddin_(politician)
# 2024-10-14 00:35:25,994 - INFO - Processing Fazlul_Haque_Montu
# 2024-10-14 00:35:27,345 - INFO - Processing Mujahidul_Islam_Selim
# 2024-10-14 00:35:28,634 - INFO - Processing Mujibur_Rahman_(Chattogram_politician)
# 2024-10-14 00:35:30,556 - INFO - Processing Shafiul_Alam_Chowdhury_Nadel
# 2024-10-14 00:35:32,553 - INFO - Processing SM_Nuruzzaman
# 2024-10-14 00:35:34,294 - INFO - Processing Shamsul_Huda_Panchbagi
# 2024-10-14 00:35:35,751 - INFO - Processing Muhammad_Bayazeed_Khan_Panni
# 2024-10-14 00:35:37,181 - INFO - Processing Ferdous_Ahmed_Qureshi
# 2024-10-14 00:35:38,535 - INFO - Processing Asheq_Ullah_Rafiq
# 2024-10-14 00:35:40,134 - INFO - Processing Abdur_Rahim_(scholar)
# 2024-10-14 00:35:41,485 - INFO - Processing Habibar_Rahman
# 2024-10-14 00:35:42,826 - INFO - Processing M._M._Rahmatullah
# 2024-10-14 00:35:44,660 - INFO - Processing Golam_Maula_Rony
# 2024-10-14 00:35:46,069 - INFO - Processing Devasish_Roy
# 2024-10-14 00:35:47,416 - INFO - Processing Mahmudul_Haque_Sayem
# 2024-10-14 00:35:48,889 - INFO - Processing Maulana_Shakhawat
# 2024-10-14 00:35:50,175 - INFO - Processing Abul_Kalam_Shamsuddin
# 2024-10-14 00:35:51,548 - INFO - Processing Badruddoza_Ahmed_Shuja
# 2024-10-14 00:35:52,909 - INFO - Processing Sourendra_Nath_Chakraborty
# 2024-10-14 00:35:54,410 - INFO - Processing Mohammad_Sultan
# 2024-10-14 00:35:55,881 - INFO - Processing Syed_Sayedul_Haque_Suman
# 2024-10-14 00:35:57,316 - INFO - Processing Mohammad_Toaha
# 2024-10-14 00:35:58,695 - INFO - Processing Badruddin_Umar
# 2024-10-14 00:36:00,159 - INFO - Processing Zahidunnabi_Dewan_Shamim
# 2024-10-14 00:36:01,438 - INFO - Processing Mohammad_Zillur_Rahman
# 2024-10-14 00:36:02,798 - INFO - Processing Elliott_Belgrave
# 2024-10-14 00:36:04,297 - INFO - Processing Chad_Blackman
# 2024-10-14 00:36:05,603 - INFO - Processing Santia_Bradshaw
# 2024-10-14 00:36:07,270 - INFO - Processing Sonia_Browne
# 2024-10-14 00:36:08,802 - INFO - Processing Michael_A._Carrington
# 2024-10-14 00:36:10,225 - INFO - Processing William_Fondleroy_Duguid
# 2024-10-14 00:36:11,656 - INFO - Processing Reginald_Farley
# 2024-10-14 00:36:13,032 - INFO - Processing Adrian_Forde
# 2024-10-14 00:36:14,356 - INFO - Processing Cynthia_Y._Forde
# 2024-10-14 00:36:15,647 - INFO - Processing Ian_Gooding-Edghill
# 2024-10-14 00:36:16,977 - INFO - Processing Damien_K._A._Griffith
# 2024-10-14 00:36:18,868 - INFO - Processing Crystal_Haynes
# 2024-10-14 00:36:20,526 - INFO - Processing Philip_St._Hill
# 2024-10-14 00:36:21,788 - INFO - Processing Kirk_Matthew_Humphrey
# 2024-10-14 00:36:23,124 - INFO - Processing Davidson_Ishmael
# 2024-10-14 00:36:24,764 - INFO - Processing Colin_Everett_Jordan
# 2024-10-14 00:36:26,043 - INFO - Processing John_Andrew_King
# 2024-10-14 00:36:27,485 - INFO - Processing Shantal_Munro-Knight
# 2024-10-14 00:36:28,705 - INFO - Processing Glyne_Murray
# 2024-10-14 00:36:30,074 - INFO - Processing Charles_Duncan_O'Neal
# 2024-10-14 00:36:31,756 - INFO - Processing Samuel_Jackman_Prescod
# 2024-10-14 00:36:33,485 - INFO - Processing Shanika_Roberts-Odle
# 2024-10-14 00:36:35,854 - INFO - Processing Ryan_Straughn
# 2024-10-14 00:36:37,372 - INFO - Processing Dwight_Sutherland
# 2024-10-14 00:36:39,535 - INFO - Processing Kerrie_Symmonds
# 2024-10-14 00:36:40,897 - INFO - Processing Yury_Ambrazevich
# 2024-10-14 00:36:42,389 - INFO - Processing Aliaksandr_Azarau
# 2024-10-14 00:36:43,724 - INFO - Processing Lyavon_Barshchewski
# 2024-10-14 00:36:45,122 - INFO - Processing Siarhei_Cherachen
# 2024-10-14 00:36:46,432 - INFO - Processing Zmitser_Dashkevich
# 2024-10-14 00:36:47,797 - INFO - Processing Siamion_Domash
# 2024-10-14 00:36:49,070 - INFO - Processing Tsimafei_Dranchuk
# 2024-10-14 00:36:50,444 - INFO - Processing Alaksandar_Dubko
# 2024-10-14 00:36:52,030 - INFO - Processing Gennady_Grushevoy
# 2024-10-14 00:36:53,427 - INFO - Processing Moshe_Gutman
# 2024-10-14 00:36:54,755 - INFO - Processing Uładzimir_Hančaryk
# 2024-10-14 00:36:56,044 - INFO - Processing Tamaš_Hryb
# 2024-10-14 00:36:57,368 - INFO - Processing Anatoĺ_Kalinin
# 2024-10-14 00:36:58,628 - INFO - Processing Voĺha_Karač
# 2024-10-14 00:37:00,034 - INFO - Processing Uładzisłau_Kazłouski
# 2024-10-14 00:37:01,399 - INFO - Processing Tadeusz_Kościuszko
# 2024-10-14 00:37:03,895 - INFO - Processing Ivan_Kubrakov
# 2024-10-14 00:37:05,430 - INFO - Processing Vladimir_Kumets
# 2024-10-14 00:37:06,843 - INFO - Processing Valery_Levaneuski
# 2024-10-14 00:37:08,249 - INFO - Processing Uladzimir_Mackievič
# 2024-10-14 00:37:10,050 - INFO - Processing V._L._Mukha
# 2024-10-14 00:37:11,343 - INFO - Processing Jan_Pazniak
# 2024-10-14 00:37:12,637 - INFO - Processing Aleksandr_Potupa
# 2024-10-14 00:37:14,107 - INFO - Processing Pyotr_Prakapovich
# 2024-10-14 00:37:15,477 - INFO - Processing Alexander_Radkov
# 2024-10-14 00:37:16,748 - INFO - Processing Symon_Rak-Michajłoŭski
# 2024-10-14 00:37:18,366 - INFO - Processing Vladimir_Rusakevich
# 2024-10-14 00:37:19,849 - INFO - Processing Ihar_Rynkevich
# 2024-10-14 00:37:21,177 - INFO - Processing Valery_Sakhashchyk
# 2024-10-14 00:37:22,676 - INFO - Processing Dominik_Semashko
# 2024-10-14 00:37:24,579 - INFO - Processing Aliaksandr_Shakutsin
# 2024-10-14 00:37:26,195 - INFO - Processing Nikolai_Shelyagovich
# 2024-10-14 00:37:27,943 - INFO - Processing Jan_Stankievič
# 2024-10-14 00:37:29,672 - INFO - Processing Mikola_Statkevich
# 2024-10-14 00:37:31,396 - INFO - Processing Sergei_Tikhanovsky
# 2024-10-14 00:37:34,015 - INFO - Processing Aleksandr_Turchin
# 2024-10-14 00:37:36,057 - INFO - Processing Yury_Voskresensky
# 2024-10-14 00:37:38,153 - INFO - Processing Edward_Woyniłłowicz
# 2024-10-14 00:37:39,976 - INFO - Processing Ivan_Yermachenka
# 2024-10-14 00:37:41,824 - INFO - Processing Manuel_Abramowicz
# 2024-10-14 00:37:43,930 - INFO - Processing Rudy_Aernoudt
# 2024-10-14 00:37:46,084 - INFO - Processing Herman_Baltia
# ...
# 2024-10-14 03:07:45,668 - INFO - Processing Guillermo_Chifflet
# 2024-10-14 03:07:46,905 - INFO - Processing Laura_Cortinas
# 2024-10-14 03:07:48,176 - INFO - Processing Guillermo_Domenech
# 2024-10-14 03:07:49,512 - INFO - Processing Lorenzo_Antonio_Fernández
# 2024-10-14 03:07:50,773 - INFO - Processing Pedro_Figari
# 2024-10-14 03:07:53,384 - INFO - Processing Liliam_Kechichián
# 2024-10-14 03:07:54,782 - INFO - Processing Dámaso_Antonio_Larrañaga
# 2024-10-14 03:07:56,150 - INFO - Processing Juan_Francisco_Larrobla
# 2024-10-14 03:07:57,478 - INFO - Processing Eduardo_Lorier
# 2024-10-14 03:07:58,858 - INFO - Processing Hector_Luisi
# 2024-10-14 03:08:00,160 - INFO - Processing Guido_Manini_Ríos
# 2024-10-14 03:08:01,745 - INFO - Processing Isidoro_de_María
# 2024-10-14 03:08:02,983 - INFO - Processing Luis_Melián_Lafinur
# 2024-10-14 03:08:04,257 - INFO - Processing Antonio_Mercader
# 2024-10-14 03:08:05,573 - INFO - Processing Pablo_Mieres
# 2024-10-14 03:08:07,088 - INFO - Processing José_Benito_Monterroso
# 2024-10-14 03:08:08,355 - INFO - Processing Tristán_Narvaja
# 2024-10-14 03:08:09,676 - INFO - Processing Gonzalo_Nin_Novoa
# 2024-10-14 03:08:10,930 - INFO - Processing Edgardo_Novick
# 2024-10-14 03:08:12,199 - INFO - Processing María_Inés_Obaldía
# 2024-10-14 03:08:13,530 - INFO - Processing Yamandú_Orsi
# 2024-10-14 03:08:14,939 - INFO - Processing José_Brito_del_Pino
# 2024-10-14 03:08:16,342 - INFO - Processing Enrique_Pintado
# 2024-10-14 03:08:17,612 - INFO - Processing Carlos_Pita_(politician)
# 2024-10-14 03:08:18,923 - INFO - Processing Carlos_Quijano
# 2024-10-14 03:08:20,290 - INFO - Processing Laura_Raffo
# 2024-10-14 03:08:21,886 - INFO - Processing José_Rondeau
# 2024-10-14 03:08:23,231 - INFO - Processing Florencio_Sánchez
# 2024-10-14 03:08:24,554 - INFO - Processing José_Pedro_Varela
# 2024-10-14 03:08:25,942 - INFO - Processing Pedro_Vaz_(diplomat)
# 2024-10-14 03:08:27,180 - INFO - Processing Mateo_Vidal
# 2024-10-14 03:08:28,453 - INFO - Processing Jorge_Zabalza
# 2024-10-14 03:08:29,835 - INFO - Processing Ikhtiyor_Abdullayev
# 2024-10-14 03:08:31,119 - INFO - Processing Adham_Ahmedbaev
# 2024-10-14 03:08:32,402 - INFO - Processing Jakhongir_Artikkhodjayev
# 2024-10-14 03:08:33,823 - INFO - Processing Valery_Ataev
# 2024-10-14 03:08:35,223 - INFO - Processing Abdusalom_Azizov
# 2024-10-14 03:08:36,634 - INFO - Processing Uktam_Barnoev
# 2024-10-14 03:08:38,112 - INFO - Processing Sa'dulla_Begaliyev
# 2024-10-14 03:08:39,371 - INFO - Processing Torokul_Dzhanuzakov
# 2024-10-14 03:08:40,682 - INFO - Processing Rustam_Inoyatov
# 2024-10-14 03:08:42,067 - INFO - Processing Rashid_Kadyrov
# 2024-10-14 03:08:43,387 - INFO - Processing Karim_Kamalov
# 2024-10-14 03:08:44,747 - INFO - Processing Tatyana_Karimova
# 2024-10-14 03:08:46,136 - INFO - Processing Erkin_Khalilov
# 2024-10-14 03:08:47,466 - INFO - Processing Sherzodkhon_Kudratkhuja
# 2024-10-14 03:08:48,854 - INFO - Processing Bakhodir_Kurbanov_(general)
# 2024-10-14 03:08:50,203 - INFO - Processing Jahangir_Mamatov
# 2024-10-14 03:08:51,531 - INFO - Processing Rimajon_Xudoyberganova
# 2024-10-14 03:08:52,822 - INFO - Processing Boʻritosh_Mustafoyev
# 2024-10-14 03:08:54,160 - INFO - Processing Bahrom_Norqobilov
# 2024-10-14 03:08:55,440 - INFO - Processing Narzullo_Oblomurodov
# 2024-10-14 03:08:56,691 - INFO - Processing Ravshanbek_Qurbonov
# 2024-10-14 03:08:57,987 - INFO - Processing Baxtiyor_Rahimov
# 2024-10-14 03:08:59,294 - INFO - Processing Bekjon_Rakhmonov
# 2024-10-14 03:09:00,853 - INFO - Processing Bakhodir_Khan_Turkistan
# 2024-10-14 03:09:02,303 - INFO - Processing Qobul_Tursunov
# 2024-10-14 03:09:03,608 - INFO - Processing Vincent_Lunabek
# 2024-10-14 03:09:05,016 - INFO - Processing President_of_Vanuatu
# 2024-10-14 03:09:06,364 - INFO - Processing Jimmy_Stevens_(politician)
# 2024-10-14 03:09:07,625 - INFO - Processing Dinh_Van_Than
# 2024-10-14 03:09:09,014 - INFO - Processing Fernando_Adames_Torres
# 2024-10-14 03:09:10,277 - INFO - Processing Ivonne_Attas
# 2024-10-14 03:09:11,696 - INFO - Processing Fidel_Barbarito
# 2024-10-14 03:09:13,057 - INFO - Processing Pedro_Bastidas
# 2024-10-14 03:09:14,461 - INFO - Processing Alejandra_Benítez
# 2024-10-14 03:09:15,879 - INFO - Processing José_Brito_(politician)
# 2024-10-14 03:09:17,853 - INFO - Processing Buenaventura_Macabeo_Maldonado_Vivas
# 2024-10-14 03:09:19,478 - INFO - Processing Rubén_González_Cárdenas
# 2024-10-14 03:09:20,903 - INFO - Processing José_Curiel
# 2024-10-14 03:09:22,176 - INFO - Processing Felix_Díaz_Ortega
# 2024-10-14 03:09:23,541 - INFO - Processing Vicente_José_Gregorio_Díaz_Silva
# 2024-10-14 03:09:25,024 - INFO - Processing Alí_Domínguez
# 2024-10-14 03:09:26,341 - INFO - Processing Franklyn_Duarte
# 2024-10-14 03:09:27,820 - INFO - Processing Alberto_Franceschi
# 2024-10-14 03:09:29,095 - INFO - Processing Arnoldo_Gabaldón
# 2024-10-14 03:09:30,507 - INFO - Processing Vladimir_Gessen_(Venezuelan_politician)
# 2024-10-14 03:09:31,799 - INFO - Processing Jorge_Giordani
# 2024-10-14 03:09:33,127 - INFO - Processing César_González_Martínez
# 2024-10-14 03:09:34,723 - INFO - Processing Luis_Graterol_Caraballo
# 2024-10-14 03:09:36,181 - INFO - Processing Liborio_Guarulla
# 2024-10-14 03:09:37,561 - INFO - Processing José_Bernabé_Gutiérrez
# 2024-10-14 03:09:38,912 - INFO - Processing María_Cristina_Iglesias
# 2024-10-14 03:09:40,271 - INFO - Processing Reinaldo_Iturriza
# 2024-10-14 03:09:41,512 - INFO - Processing Andrés_Izarra
# 2024-10-14 03:09:42,869 - INFO - Processing Reinaldo_Leandro_Mora
# 2024-10-14 03:09:44,135 - INFO - Processing Carlos_Augusto_León
# 2024-10-14 03:09:45,404 - INFO - Processing Ramón_Lobo_(economist)
# 2024-10-14 03:09:46,743 - INFO - Processing Jorge_Elieser_Márquez
# 2024-10-14 03:09:48,110 - INFO - Processing Américo_Martín
# 2024-10-14 03:09:49,688 - INFO - Processing Nelson_Martínez_(politician)
# 2024-10-14 03:09:50,936 - INFO - Processing Francisco_de_Miranda
# 2024-10-14 03:09:53,271 - INFO - Processing Reinaldo_Muñoz_Pedroza
# 2024-10-14 03:09:54,562 - INFO - Processing Dia_Nader_de_El-Andari
# 2024-10-14 03:09:55,847 - INFO - Processing Moisés_Naím
# 2024-10-14 03:09:57,263 - INFO - Processing Freddy_Ñáñez
# 2024-10-14 03:09:58,517 - INFO - Processing Pablo_Acosta_Ortiz
# 2024-10-14 03:09:59,885 - INFO - Processing Renny_Ottolina
# 2024-10-14 03:10:01,194 - INFO - Processing Alejandro_Peña_Esclusa
# 2024-10-14 03:10:02,562 - INFO - Processing Miguel_Peña_(politician)
# 2024-10-14 03:10:03,811 - INFO - Processing Lewis_Pérez
# 2024-10-14 03:10:05,455 - INFO - Processing Arkiely_Perfecto
# 2024-10-14 03:10:06,817 - INFO - Processing Eduardo_Piñate
# 2024-10-14 03:10:08,168 - INFO - Processing Humberto_Prado
# 2024-10-14 03:10:09,463 - INFO - Processing Omar_Prieto
# 2024-10-14 03:10:10,784 - INFO - Processing Benjamín_Rausseo
# 2024-10-14 03:10:12,164 - INFO - Processing Manuel_Felipe_Rugeles
# 2024-10-14 03:10:13,521 - INFO - Processing Carlos_Santana_Tovar
# 2024-10-14 03:10:14,917 - INFO - Processing Milena_Sardi_de_Selle
# 2024-10-14 03:10:16,290 - INFO - Processing Carlos_Eduardo_Stolk
# 2024-10-14 03:10:17,622 - INFO - Processing Bolivia_Suárez
# 2024-10-14 03:10:18,952 - INFO - Processing Gustavo_Tarre
# 2024-10-14 03:10:20,420 - INFO - Processing José_Herrera_Uslar
# 2024-10-14 03:10:21,667 - INFO - Processing Addy_Valero
# 2024-10-14 03:10:22,949 - INFO - Processing José_Antonio_Velutini
# 2024-10-14 03:10:24,256 - INFO - Processing Henry_Ventura
# 2024-10-14 03:10:25,495 - INFO - Processing Nervis_Villalobos
# 2024-10-14 03:10:26,814 - INFO - Processing Bùi_Tiến_Dũng_(politician)
# 2024-10-14 03:10:28,194 - INFO - Processing Chu_Văn_An
# 2024-10-14 03:10:31,215 - INFO - Processing Nguyễn_Quốc_Định
# 2024-10-14 03:10:32,552 - INFO - Processing Đinh_Xuân_Quảng
# 2024-10-14 03:10:34,129 - INFO - Processing Kiem_Do
# 2024-10-14 03:10:35,407 - INFO - Processing Đỗ_Quang_Giai
# 2024-10-14 03:10:36,672 - INFO - Processing Hồ_Đắc_Điềm
# 2024-10-14 03:10:38,008 - INFO - Processing Hồ_Văn_Nhựt
# 2024-10-14 03:10:39,562 - INFO - Processing Hoàng_Cao_Khải
# 2024-10-14 03:10:40,871 - INFO - Processing Hoang_Van_Chi
# 2024-10-14 03:10:42,546 - INFO - Processing Huỳnh_Văn_Cao
# 2024-10-14 03:10:43,912 - INFO - Processing Kiều_Mộng_Thu
# 2024-10-14 03:10:45,328 - INFO - Processing Lê_Minh_Hương
# 2024-10-14 03:10:46,614 - INFO - Processing Lê_Quốc_Minh
# 2024-10-14 03:10:48,037 - INFO - Processing Lê_Văn_Thành
# 2024-10-14 03:10:49,346 - INFO - Processing Lương_Thế_Huy
# 2024-10-14 03:10:50,594 - INFO - Processing Nguyễn_Hồng_Diên
# 2024-10-14 03:10:52,022 - INFO - Processing Nguyễn_Đức_Chung
# 2024-10-14 03:10:53,327 - INFO - Processing Nguyễn_Dương_Đôn
# 2024-10-14 03:10:54,650 - INFO - Processing Nguyễn_Duy_Quý
# 2024-10-14 03:10:55,898 - INFO - Processing Nguyễn_Hợp_Đoàn
# 2024-10-14 03:10:57,239 - INFO - Processing Nguyễn_Phan_Long
# 2024-10-14 03:10:58,527 - INFO - Processing Nguyễn_Quốc_Cường
# 2024-10-14 03:10:59,835 - INFO - Processing Nguyễn_Thị_Hồng_(economist)
# 2024-10-14 03:11:01,376 - INFO - Processing Nguyễn_Thị_Thập
# 2024-10-14 03:11:02,594 - INFO - Processing Nguyễn_Văn_Huyền
# 2024-10-14 03:11:04,110 - INFO - Processing Nguyễn_Văn_Lực
# 2024-10-14 03:11:05,403 - INFO - Processing Nguyễn_Văn_Trân
# 2024-10-14 03:11:06,685 - INFO - Processing Nguyễn_Văn_Xuân
# 2024-10-14 03:11:07,982 - INFO - Processing Phan_Anh
# 2024-10-14 03:11:09,246 - INFO - Processing Tạ_Quang_Bửu
# 2024-10-14 03:11:10,681 - INFO - Processing Tran_Minh_Tiet
# 2024-10-14 03:11:12,058 - INFO - Processing Trần_Quốc_Vượng_(politician)
# 2024-10-14 03:11:13,653 - INFO - Processing Trần_Văn_Hữu
# 2024-10-14 03:11:15,024 - INFO - Processing Trương_Đình_Dzu
# 2024-10-14 03:11:16,522 - INFO - Processing Võ_Văn_Thưởng
# 2024-10-14 03:11:18,309 - INFO - Processing Abdullah_Noman
# 2024-10-14 03:11:19,567 - INFO - Processing Hashid_Abdullah_al-Ahmar
# 2024-10-14 03:11:20,929 - INFO - Processing Himyar_Abdullah_al-Ahmar
# 2024-10-14 03:11:22,178 - INFO - Processing Sam_Yahya_Al-Ahmar
# 2024-10-14 03:11:23,521 - INFO - Processing Ameen_Ali_al-Akimi
# 2024-10-14 03:11:24,837 - INFO - Processing Talal_Aklan
# 2024-10-14 03:11:26,097 - INFO - Processing Abdullatif_Al-Sayed
# 2024-10-14 03:11:27,480 - INFO - Processing Muhammad_Musa_al-Amri
# 2024-10-14 03:11:28,868 - INFO - Processing Mohamed_al-Atifi
# 2024-10-14 03:11:30,200 - INFO - Processing Yasser_Al-Awadi
# 2024-10-14 03:11:31,565 - INFO - Processing Sagheer_Hamoud_Aziz
# 2024-10-14 03:11:32,920 - INFO - Processing Sultan_al-Barakani
# 2024-10-14 03:11:34,308 - INFO - Processing Faraj_Salmin_Al-Bahsani
# 2024-10-14 03:11:35,581 - INFO - Processing Ali_Al_Bukhaiti
# 2024-10-14 03:11:36,879 - INFO - Processing Bruce_Conde
# 2024-10-14 03:11:38,196 - INFO - Processing Abdul_Wahab_Al-Dailami
# 2024-10-14 03:11:39,559 - INFO - Processing Ali_Ahmad_Nasser_al-Dhahab
# 2024-10-14 03:11:40,793 - INFO - Processing Badreddin_al-Houthi
# 2024-10-14 03:11:42,057 - INFO - Processing Ibrahim_Bin_Ali_Al_Wazeer
# 2024-10-14 03:11:43,446 - INFO - Processing Mohammed_Lutf_al-Iryani
# 2024-10-14 03:11:44,728 - INFO - Processing Abd_Al-Rahman_Ali_Al-Jifri
# 2024-10-14 03:11:46,133 - INFO - Processing Hussein_Khairan
# 2024-10-14 03:11:47,439 - INFO - Processing Mohammed_Ali_Al-Maqdashi
# 2024-10-14 03:11:48,701 - INFO - Processing Hooria_Mashhour
# 2024-10-14 03:11:50,003 - INFO - Processing Muhammad_bin_Yahya_bin_Muhammad
# 2024-10-14 03:11:51,346 - INFO - Processing Abdul_Qader_Qahtan
# 2024-10-14 03:11:52,645 - INFO - Processing Abdulwahab_al-Rawhani
# 2024-10-14 03:11:54,003 - INFO - Processing Mohammed_al-Sabry
# 2024-10-14 03:11:55,231 - INFO - Processing Yahya_Mohamed_Abdullah_Saleh
# 2024-10-14 03:11:56,661 - INFO - Processing Ali_Taysir
# 2024-10-14 03:11:57,912 - INFO - Processing Yahya_Muhammad_Hamid_ed-Din
# 2024-10-14 03:11:59,621 - INFO - Processing Aidarus_al-Zoubaidi
# 2024-10-14 03:12:00,912 - INFO - Processing Francis_Kapyanga
# 2024-10-14 03:12:02,197 - INFO - Processing Lily_Monze
# 2024-10-14 03:12:03,470 - INFO - Processing Olipa_Phiri
# 2024-10-14 03:12:04,733 - INFO - Processing Gift_Banda
# 2024-10-14 03:12:06,003 - INFO - Processing Flora_Buka
# 2024-10-14 03:12:07,253 - INFO - Processing Bulelani_Lobengula
# 2024-10-14 03:12:08,646 - INFO - Processing Joseph_Makamba_Busha
# 2024-10-14 03:12:10,009 - INFO - Processing Darlington_Dzikamai_Chigumbu
# 2024-10-14 03:12:11,291 - INFO - Processing James_Chikerema
# 2024-10-14 03:12:12,585 - INFO - Processing Paul_Chimedza
# 2024-10-14 03:12:13,907 - INFO - Processing Chenhamo_Chimutengwende
# 2024-10-14 03:12:15,341 - INFO - Processing Ruth_Chinamano
# 2024-10-14 03:12:16,754 - INFO - Processing George_Chiweshe
# 2024-10-14 03:12:18,007 - INFO - Processing Phillip_Chiyangwa
# 2024-10-14 03:12:19,443 - INFO - Processing Guy_Clutton-Brock
# 2024-10-14 03:12:20,747 - INFO - Processing Margaret_Dongo
# 2024-10-14 03:12:22,045 - INFO - Processing Jabulani_Dube
# 2024-10-14 03:12:23,385 - INFO - Processing Fletcher_Dulini_Ncube
# 2024-10-14 03:12:24,719 - INFO - Processing Ken_Flower
# 2024-10-14 03:12:25,982 - INFO - Processing Aguy_Georgias
# 2024-10-14 03:12:27,363 - INFO - Processing Sithembile_Gumbo
# 2024-10-14 03:12:28,659 - INFO - Processing Josiah_Zion_Gumede
# 2024-10-14 03:12:30,061 - INFO - Processing Ellen_Gwaradzimba
# 2024-10-14 03:12:31,329 - INFO - Processing Andre_Sothern_Holland
# 2024-10-14 03:12:32,601 - INFO - Processing Byron_Hove
# 2024-10-14 03:12:33,995 - INFO - Processing Tonderai_Kasu
# 2024-10-14 03:12:35,335 - INFO - Processing Wilson_Khumbula
# 2024-10-14 03:12:36,744 - INFO - Processing Lovemore_Madhuku
# 2024-10-14 03:12:38,230 - INFO - Processing Sarah_Mahoka
# 2024-10-14 03:12:39,536 - INFO - Processing Alfred_Makwarimba
# 2024-10-14 03:12:40,790 - INFO - Processing Washington_Malianga
# 2024-10-14 03:12:42,030 - INFO - Processing Elliot_Manyika
# 2024-10-14 03:12:43,559 - INFO - Processing Linda_Masarira
# 2024-10-14 03:12:44,838 - INFO - Processing Jevan_Maseko
# 2024-10-14 03:12:46,100 - INFO - Processing Anxious_Masuka
# 2024-10-14 03:12:47,419 - INFO - Processing Lovemore_Matombo
# 2024-10-14 03:12:48,832 - INFO - Processing Bright_Matonga
# 2024-10-14 03:12:50,176 - INFO - Processing Isaac_Matongo
# 2024-10-14 03:12:51,465 - INFO - Processing Obedingwa_Mguni
# 2024-10-14 03:12:52,900 - INFO - Processing Promise_Mkwananzi
# 2024-10-14 03:12:54,262 - INFO - Processing Max_Mnkandla
# 2024-10-14 03:12:55,599 - INFO - Processing Bekithemba_Mpofu
# 2024-10-14 03:12:57,288 - INFO - Processing Earnest_Mudzengi
# 2024-10-14 03:12:58,585 - INFO - Processing Mugabe_family
# 2024-10-14 03:12:59,925 - INFO - Processing Kisinoti_Mukwazhe
# 2024-10-14 03:13:01,435 - INFO - Processing Edwin_Mushoriwa
# 2024-10-14 03:13:02,690 - INFO - Processing Munacho_Mutezo
# 2024-10-14 03:13:04,026 - INFO - Processing Abel_Muzorewa
# 2024-10-14 03:13:05,457 - INFO - Processing Prag_Lalloo_Naran
# 2024-10-14 03:13:06,865 - INFO - Processing Owen_Ncube
# 2024-10-14 03:13:08,199 - INFO - Processing Nhlanhlayamangwe_Felix_Ndiweni
# 2024-10-14 03:13:09,540 - INFO - Processing Gundwane_Ndiweni
# 2024-10-14 03:13:10,915 - INFO - Processing Khayisa_Ndiweni
# 2024-10-14 03:13:12,308 - INFO - Processing Jane_Ngwenya
# 2024-10-14 03:13:13,637 - INFO - Processing Maurice_Nyagumbo
# 2024-10-14 03:13:14,930 - INFO - Processing George_Nyandoro
# 2024-10-14 03:13:16,308 - INFO - Processing Sekai_Nzenza
# 2024-10-14 03:13:17,564 - INFO - Processing Engelbert_Rugeje
# 2024-10-14 03:13:18,876 - INFO - Processing Tinos_Rusere
# 2024-10-14 03:13:20,155 - INFO - Processing Scot_Sakupwanya
# 2024-10-14 03:13:21,471 - INFO - Processing Daniel_Shumba
# 2024-10-14 03:13:23,612 - INFO - Processing Maxwell_Zeb_Shumba
# 2024-10-14 03:13:24,904 - INFO - Processing Nkululeko_Mkastos_Sibanda
# 2024-10-14 03:13:26,230 - INFO - Processing Leopold_Takawira
# 2024-10-14 03:13:27,585 - INFO - Processing Gift_Tandare
# 2024-10-14 03:13:28,894 - INFO - Processing Rekayi_Tangwena
# 2024-10-14 03:13:30,150 - INFO - Processing Temba_Mliswa
# 2024-10-14 03:13:31,624 - INFO - Processing Josiah_Tongogara
# 2024-10-14 03:13:33,101 - INFO - Processing Langton_Towungana
# 2024-10-14 03:13:34,360 - INFO - Processing Sengezo_Tshabangu
# 2024-10-14 03:13:35,634 - INFO - Processing Herbert_Ushewokunze
# 2024-10-14 03:13:37,019 - INFO - Processing Denis_Walker
# 2024-10-14 03:13:38,632 - INFO - Error rate: 0.11%

# %% [markdown]
# ### Merging Wikipedia Politicians Data with Population Data
# In this section, we perform the following steps:
# 1. **Load Data**: Load the cleaned Wikipedia politicians dataset (`politicians_with_quality.csv`) and the population data (`population_by_country_AUG.2024.csv`).
# 2. **Assign Regions to Countries**: Process the population data to assign regions to countries, using uppercase entries to identify regions.
# 3. **Standardize Country Names**: Handle inconsistencies in country names (e.g., variations of "China" and "Guinea-Bissau").
# 4. **Merge Datasets**: Perform an outer merge on the `country` field to ensure both datasets align correctly.
# 5. **Log Non-Matching Countries**: Identify countries that are missing from either dataset and save them to a log file.
# 6. **Filter and Save Matched Data**: Filter the merged data to include only matching countries and save the cleaned dataset to a CSV file.

# %%
import pandas as pd

# Step 1: Load the Wikipedia politicians data and population data
# This includes the processed politicians data with quality scores and the population dataset with regions
politicians_df = pd.read_csv('../data/politicians_with_quality.csv')
population_df_new = pd.read_csv('../data/population_by_country_AUG.2024.csv')

# Step 2: Process the population data to assign regions to countries
# We use an iterative approach, identifying regions (uppercase entries) and associating countries with their regions
current_region = None  # Tracks the current region during iteration
processed_pop_data = []  # List to hold the processed data with region-country-population associations

# Iterate through each row in the population data
for _, row in population_df_new.iterrows():
    geography = row['Geography']
    
    # If the name is in all caps, it's a region
    if geography.isupper():
        current_region = geography  # Set the current region
    else:
        # If it's a country, add its country name, region, and population to the processed list
        processed_pop_data.append({
            'country': geography.lower().strip(),  # Standardizing country names (lowercase, no spaces)
            'region': current_region,              # The associated region
            'population': row['Population']        # Population value
        })

# Convert the processed population data into a DataFrame for merging later
pop_df = pd.DataFrame(processed_pop_data)

# Step 3: Standardize country names in the Wikipedia data
# This ensures consistent formatting of country names for merging
politicians_df['country'] = politicians_df['country'].str.lower().str.strip()

# Step 4: Handle special cases (China, Guinea-Bissau, etc.) using a name_map dictionary
# These cases address variations or inconsistencies in country names across the two datasets
name_map = {
    "china (hong kong sar)": "china",
    "china (macao sar)": "china",
    "guinea-bissau": "guinea-bissau",
    "guineabissau": "guinea-bissau"
}

# Apply the name_map to both datasets to standardize country names for matching
politicians_df['country'] = politicians_df['country'].replace(name_map)
pop_df['country'] = pop_df['country'].replace(name_map)

# Step 5: Perform an outer merge on 'country' between politicians_df and pop_df
# This ensures that we don't lose data from either dataset, even if a country is missing in one
merged_df = pd.merge(politicians_df, pop_df, on='country', how='outer', indicator=True)

# Step 6: Identify unmatched countries and write them to a file
# These are countries that exist in one dataset but not the other, and we'll save them for review
non_matches = merged_df[merged_df['_merge'] != 'both']
non_matching_countries = non_matches['country'].dropna().unique()

# Write the non-matching countries to a text file for troubleshooting
with open('../data/wp_countries-no_match.txt', 'w') as f:
    for country in non_matching_countries:
        f.write(f"{country}\n")

# Step 7: Filter for matched data (countries present in both datasets)
# We only keep rows where there is a match between both datasets
matched_data = merged_df[merged_df['_merge'] == 'both']

# Step 8: Select relevant columns for the final dataset
# This includes country, region, population, and article-related fields
final_columns = ['country', 'region', 'population', 'name', 'revision_id', 'quality_score']
final_df = matched_data[final_columns]

# Step 9: Rename the columns to be more meaningful
# This makes the column names more descriptive
final_df.rename(columns={
    'name': 'article_title',
    'quality_score': 'article_quality'
}, inplace=True)

# Step 10: Save the consolidated final DataFrame to a CSV file for future analysis
final_df.to_csv('../data/wp_politicians_by_country.csv', index=False)

# Quick preview of the final DataFrame to verify the results
print(final_df.head())
# Out:
#        country      region  population         article_title   revision_id  \
# 0  afghanistan  SOUTH ASIA        42.4        Majah Ha Adrif  1.233203e+09
# 1  afghanistan  SOUTH ASIA        42.4     Haroon al-Afghani  1.230460e+09
# 2  afghanistan  SOUTH ASIA        42.4           Tayyab Agha  1.225662e+09
# 3  afghanistan  SOUTH ASIA        42.4  Khadija Zahra Ahmadi  1.234742e+09
# 4  afghanistan  SOUTH ASIA        42.4        Aziza Ahmadyar  1.195651e+09
#
#   article_quality
# 0           Start
# 1               B
# 2           Start
# 3            Stub
# 4           Start
# /var/folders/x8/4fwkd70s40s_wrt2mnhq6rdw0000gn/T/ipykernel_72795/4047874980.py:64: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df.rename(columns={

# %% [markdown]
# ### Handling Missing `revision_id`
# In this step, we clean the dataset by removing rows where the `revision_id` is missing. This field is essential for retrieving the article quality score from the ORES API, so any row missing this value is excluded from further analysis. The steps include:
# 1. **Identify Missing `revision_id`**: Create a subset of rows where `revision_id` is NaN (missing).
# 2. **Remove Rows with Missing `revision_id`**: Filter the DataFrame to exclude these rows.
# 3. **Log Missing Data**: Optionally save rows with missing `revision_id` to a log file for review.

# %%
# Step 11: Handle Rows with Missing 'revision_id'
# In this part, we'll handle rows where the 'revision_id' is missing.
# Since 'revision_id' is critical to retrieve the quality score from ORES,
# we need to remove any rows where this value is missing.

# Step 11.1: Identify rows with missing 'revision_id'
# We'll create a subset of rows where 'revision_id' is NaN (not available).
rows_with_missing_revision = final_df[final_df['revision_id'].isna()]

# Step 11.2: Remove rows where 'revision_id' is missing
# Now, we filter out the rows with missing 'revision_id' from the main DataFrame to ensure data accuracy.
final_df_filtered = final_df.dropna(subset=['revision_id'])

# Step 11.3: Log missing rows for review
# Save the rows with missing 'revision_id' to a separate file for review (optional).
rows_with_missing_revision.to_csv('../data/ores_error_log.txt', index=False)

# Step 11.4: Quick preview of the cleaned data after removing rows with missing 'revision_id'
# Let's print the cleaned DataFrame to verify that the missing rows have been successfully removed.
print(final_df_filtered.head())

# Step 11.5: Save the cleaned data to a new CSV file
# This cleaned dataset will be used for further analysis.
final_df_filtered.to_csv('../data/wp_politicians_by_country_clean.csv', index=False)
# Out:
#        country      region  population         article_title   revision_id  \
# 0  afghanistan  SOUTH ASIA        42.4        Majah Ha Adrif  1.233203e+09
# 1  afghanistan  SOUTH ASIA        42.4     Haroon al-Afghani  1.230460e+09
# 2  afghanistan  SOUTH ASIA        42.4           Tayyab Agha  1.225662e+09
# 3  afghanistan  SOUTH ASIA        42.4  Khadija Zahra Ahmadi  1.234742e+09
# 4  afghanistan  SOUTH ASIA        42.4        Aziza Ahmadyar  1.195651e+09
#
#   article_quality
# 0           Start
# 1               B
# 2           Start
# 3            Stub
# 4           Start

# %% [markdown]
# ### Calculating Total and High-Quality Articles Per Capita (Country and Region Level)
# In this step, we compute two key metrics to analyze the coverage and quality of Wikipedia articles for politicians:
# 1. **Total Articles Per Capita**: Number of articles about politicians per person, using population data.
# 2. **High-Quality Articles Per Capita**: Number of high-quality articles (those classified as "FA" or "GA") per person.
#
# This is calculated for both country and region levels, ensuring that we aggregate data correctly and calculate per capita metrics for comparison.

# %%
# Step 1: Define high-quality classes
# We're defining 'FA' (Featured Article) and 'GA' (Good Article) as high-quality articles based on ORES scoring.
high_quality_classes = ["FA", "GA"]

# Step 2: Mark high-quality articles
# Here, we're adding a new column 'high_quality' to the DataFrame to mark whether an article is of high quality.
final_df_filtered['high_quality'] = final_df_filtered['article_quality'].apply(lambda x: x in high_quality_classes)

# Step 3: Group data by country to calculate total and high-quality articles
# We group the data by country and calculate:
# - Total articles per country (count of articles)
# - High-quality articles per country (sum of high-quality articles)
# - Population for each country (using the first population entry since it doesn't change per article)
country_grouped = final_df_filtered.groupby('country').agg(
    total_articles=('article_title', 'count'),
    high_quality_articles=('high_quality', 'sum'),
    population=('population', 'first')  # Population should be the same for all articles in a country
).reset_index()

# Step 4: Calculate per capita metrics
# Now we calculate the total articles per capita and high-quality articles per capita for each country.
# This is done by dividing the article counts by the population.
country_grouped['total_articles_per_capita'] = country_grouped['total_articles'] / country_grouped['population']
country_grouped['high_quality_articles_per_capita'] = country_grouped['high_quality_articles'] / country_grouped['population']

# Step 5: Group data by both region and country
# Grouping by both region and country to ensure that each country's population is only counted once in regional aggregates.
grouped = final_df_filtered.groupby(['region', 'country']).agg(
    total_articles=('article_title', 'count'),
    high_quality_articles=('high_quality', 'sum'),
    population=('population', 'first')
).reset_index()

# Step 6: Aggregate data by region
# After grouping by both region and country, we then aggregate the results by region.
# We sum the total articles, high-quality articles, and population across all countries within each region.
region_grouped = grouped.groupby('region').agg(
    total_articles=('total_articles', 'sum'),
    high_quality_articles=('high_quality_articles', 'sum'),
    population=('population', 'sum')
).reset_index()

# Step 7: Calculate regional per capita metrics
# Just like with countries, we now calculate the per capita metrics for each region.
# This is done by dividing the total articles and high-quality articles by the total population in the region.
region_grouped['total_articles_per_capita'] = region_grouped['total_articles'] / region_grouped['population']
region_grouped['high_quality_articles_per_capita'] = region_grouped['high_quality_articles'] / region_grouped['population']

# Step 8: Output results
# Now that we've calculated the metrics, let's take a look at the results for both countries and regions.
print(country_grouped.head())  # Preview the country-level metrics
print(region_grouped.head())   # Preview the region-level metrics

# Step 9: Save results to CSV files
# Finally, we save the grouped metrics to CSV files for future use or reporting.
country_grouped.to_csv('../data/country_grouped_metrics.csv', index=False)
region_grouped.to_csv('../data/region_grouped_metrics.csv', index=False)
# Out:
#                country  total_articles  high_quality_articles  population  \
# 0          afghanistan              85                      3        42.4
# 1              albania              70                      7         2.7
# 2              algeria              71                      1        46.8
# 3               angola              58                      2        36.7
# 4  antigua and barbuda              33                      0         0.1
#
#    total_articles_per_capita  high_quality_articles_per_capita
# 0                   2.004717                          0.070755
# 1                  25.925926                          2.592593
# 2                   1.517094                          0.021368
# 3                   1.580381                          0.054496
# 4                 330.000000                          0.000000
#             region  total_articles  high_quality_articles  population  \
# 0        CARIBBEAN             218                      9        36.6
# 1  CENTRAL AMERICA             188                     10        51.3
# 2     CENTRAL ASIA             106                      5        80.4
# 3        EAST ASIA             184                      3      1562.7
# 4   EASTERN AFRICA             664                     17       480.9
#
#    total_articles_per_capita  high_quality_articles_per_capita
# 0                   5.956284                          0.245902
# 1                   3.664717                          0.194932
# 2                   1.318408                          0.062189
# 3                   0.117745                          0.001920
# 4                   1.380744                          0.035350
# /var/folders/x8/4fwkd70s40s_wrt2mnhq6rdw0000gn/T/ipykernel_72795/432504258.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   final_df_filtered['high_quality'] = final_df_filtered['article_quality'].apply(lambda x: x in high_quality_classes)

# %% [markdown]
# ### Analyzing Wikipedia Politicians Coverage: Top 10 and Bottom 10 Countries by Articles Per Capita
# In this section, we will analyze Wikipedia articles about politicians by calculating the total articles per capita for each country. We'll then display the top 10 and bottom 10 countries based on this metric, while excluding countries with very small populations or missing values. Infinite values (due to zero population) are handled by replacing them with NaN and subsequently removing these entries.

# %% [markdown]
# ### Results Summary
#
# This section summarizes the coverage of Wikipedia articles about political figures across various countries and regions. We focus on two main aspects: total article coverage and high-quality article coverage.
#
# 1. **Top 10 Countries by Article Coverage**:
#    - Displays the top 10 countries with the highest number of Wikipedia articles about political figures, normalized by population.
#    - Countries with a population below 0.05 million are excluded to avoid skewed results.
#
# 2. **Bottom 10 Countries by Article Coverage**:
#    - Highlights the countries with the lowest article coverage per capita.
#    - As with the top 10, countries with a population of zero are excluded.
#
# 3. **Top 10 Countries by High-Quality Articles**:
#    - Lists the top 10 countries with the highest number of high-quality articles per capita.
#    - High-quality articles are defined as those classified as "FA" (Featured Article) or "GA" (Good Article).
#
# 4. **Bottom 10 Countries by High-Quality Articles**:
#    - Shows the countries with the lowest proportion of high-quality articles per capita.
#
# 5. **Geographic Regions by Total Coverage**:
#    - Ranks geographic regions based on the total number of articles per capita.
#
# 6. **Geographic Regions by High-Quality Coverage**:
#    - Ranks regions based on the number of high-quality articles per capita.

# %%
import pandas as pd
import numpy as np
from tabulate import tabulate

# Step 1: Load the country and region data
# We're loading the metrics that have already been processed for countries and regions
country_stats = pd.read_csv('/Users/radhikasethi/Documents/github/data-512-homework-2/data/country_grouped_metrics.csv')
region_stats = pd.read_csv('/Users/radhikasethi/Documents/github/data-512-homework-2/data/region_grouped_metrics.csv')

# Step 2: Handle infinite values in 'total_articles_per_capita'
# Replace infinite values (from zero population) with NaN, and drop rows with missing values
filtered_country_stats = country_stats.replace([np.inf, -np.inf], np.nan).dropna(subset=['total_articles_per_capita'])

# Step 3: Exclude countries with populations less than 0.05 million
# Filter out countries with very small populations since they can distort the results
filtered_country_stats = filtered_country_stats[filtered_country_stats['population'] > 0.05 * 1e6]

# Step 4: Get the top 10 countries by total articles per capita
# Sort to get the top 10 countries that have the highest number of articles per capita
top_10_countries_coverage = filtered_country_stats.nlargest(10, 'total_articles_per_capita')

# Step 5: Format the 'total_articles_per_capita' column for display
# Format to four decimal places for consistency
top_10_countries_coverage['total_articles_per_capita (per million)'] = top_10_countries_coverage['total_articles_per_capita'].apply(lambda x: format(x, '.4f'))

# Step 6: Add a rank column for clarity
# Number the countries from 1 to 10 based on their rank in coverage
top_10_countries_coverage['Rank (from the top)'] = range(1, len(top_10_countries_coverage) + 1)

# Step 7: Select relevant columns for display
# We're only interested in showing the rank, country, and the articles per capita
top_10_display = top_10_countries_coverage[['Rank (from the top)', 'country', 'total_articles_per_capita (per million)']]

# Step 8: Display the top 10 countries using tabulate for a cleaner output
# This prints the top 10 countries by articles per capita in a nicely formatted table
print("Top 10 countries by coverage-->")
print(tabulate(top_10_display, headers='keys', tablefmt='psql', showindex=False))

# Step 9: Save the top 10 countries by coverage as a CSV (optional)
# Save to CSV for future use or reporting
top_10_display.to_csv('/Users/radhikasethi/Documents/github/data-512-homework-2/data/top_10_countries_by_coverage.csv', index=False)

# Step 10: Get the bottom 10 countries by total articles per capita
# Same as the top 10 but now we're grabbing the bottom 10 countries
bottom_10_countries_coverage = filtered_country_stats.nsmallest(10, 'total_articles_per_capita')
bottom_10_countries_coverage['total_articles_per_capita (per million)'] = bottom_10_countries_coverage['total_articles_per_capita'].apply(lambda x: format(x, '.4f'))
bottom_10_countries_coverage['Rank (from the bottom)'] = range(1, len(bottom_10_countries_coverage) + 1)

# Step 11: Select relevant columns for display for the bottom 10 countries
bottom_10_display = bottom_10_countries_coverage[['Rank (from the bottom)', 'country', 'total_articles_per_capita (per million)']]

# Step 12: Display the bottom 10 countries in a clean table
print("Bottom 10 countries by coverage-->")
print(tabulate(bottom_10_display, headers='keys', tablefmt='psql', showindex=False))
# Out:
# dnkcs
#                  country  total_articles  high_quality_articles  population  \
# 0            afghanistan              85                      3        42.4
# 1                albania              70                      7         2.7
# 2                algeria              71                      1        46.8
# 3                 angola              58                      2        36.7
# 4    antigua and barbuda              33                      0         0.1
# ..                   ...             ...                    ...         ...
# 162            venezuela              56                      1        28.8
# 163              vietnam              36                      2        98.9
# 164                yemen              32                      0        34.4
# 165               zambia               3                      0        20.2
# 166             zimbabwe              69                      0        16.7
#
#      total_articles_per_capita  high_quality_articles_per_capita
# 0                     2.004717                          0.070755
# 1                    25.925926                          2.592593
# 2                     1.517094                          0.021368
# 3                     1.580381                          0.054496
# 4                   330.000000                          0.000000
# ..                         ...                               ...
# 162                   1.944444                          0.034722
# 163                   0.364004                          0.020222
# 164                   0.930233                          0.000000
# 165                   0.148515                          0.000000
# 166                   4.131737                          0.000000
#
# [165 rows x 6 columns]
# Top 10 countries by coverage-->
# +-----------------------+--------------------------------+-------------------------------------------+
# |   Rank (from the top) | country                        |   total_articles_per_capita (per million) |
# |-----------------------+--------------------------------+-------------------------------------------|
# |                     1 | antigua and barbuda            |                                  330      |
# |                     2 | federated states of micronesia |                                  140      |
# |                     3 | marshall islands               |                                  130      |
# |                     4 | tonga                          |                                  100      |
# |                     5 | barbados                       |                                   83.3333 |
# |                     6 | montenegro                     |                                   60      |
# |                     7 | seychelles                     |                                   60      |
# |                     8 | bhutan                         |                                   55      |
# |                     9 | maldives                       |                                   55      |
# |                    10 | samoa                          |                                   40      |
# +-----------------------+--------------------------------+-------------------------------------------+
# Bottom 10 countries by coverage-->
# +--------------------------+---------------+-------------------------------------------+
# |   Rank (from the bottom) | country       |   total_articles_per_capita (per million) |
# |--------------------------+---------------+-------------------------------------------|
# |                        1 | china         |                                    0.034  |
# |                        2 | ghana         |                                    0.088  |
# |                        3 | india         |                                    0.1057 |
# |                        4 | saudi arabia  |                                    0.1355 |
# |                        5 | zambia        |                                    0.1485 |
# |                        6 | norway        |                                    0.1818 |
# |                        7 | israel        |                                    0.2041 |
# |                        8 | egypt         |                                    0.3042 |
# |                        9 | cote d'ivoire |                                    0.3236 |
# |                       10 | ethiopia      |                                    0.3478 |
# +--------------------------+---------------+-------------------------------------------+

# %%
# Save the bottom 10 countries by coverage as a CSV for later use
bottom_10_display.to_csv('/Users/radhikasethi/Documents/github/data-512-homework-2/data/bottom_10_countries_by_coverage.csv', index=False)

# Step 11: Top 10 countries by high-quality articles per capita
# Find the top 10 countries based on high-quality articles per capita
top_10_countries_high_quality = filtered_country_stats.nlargest(10, 'high_quality_articles_per_capita')
top_10_countries_high_quality['high_quality_articles_per_capita (per million)'] = top_10_countries_high_quality['high_quality_articles_per_capita'].apply(lambda x: format(x, '.4f'))

# Add a rank to make it clear who's at the top
top_10_countries_high_quality['Rank (from the top)'] = range(1, len(top_10_countries_high_quality) + 1)

# Select the columns we need to display
top_10_high_quality_display = top_10_countries_high_quality[['Rank (from the top)', 'country', 'high_quality_articles_per_capita (per million)']]

# Display the top 10 countries for high-quality articles in a nice table
print("Top 10 countries by high-quality articles per capita-->")
print(tabulate(top_10_high_quality_display, headers='keys', tablefmt='psql', showindex=False))

# Save the top 10 high-quality countries to a CSV for later use
top_10_high_quality_display.to_csv('/Users/radhikasethi/Documents/github/data-512-homework-2/data/top_10_countries_by_high_quality.csv', index=False)

# Step 12: Bottom 10 countries by high-quality articles per capita
# Find the bottom 10 countries based on high-quality articles per capita
bottom_10_countries_high_quality = filtered_country_stats.nsmallest(10, 'high_quality_articles_per_capita')
bottom_10_countries_high_quality['high_quality_articles_per_capita (per million)'] = bottom_10_countries_high_quality['high_quality_articles_per_capita'].apply(lambda x: format(x, '.4f'))

# Add a rank for clarity
bottom_10_countries_high_quality['Rank (from the bottom)'] = range(1, len(bottom_10_countries_high_quality) + 1)

# Select relevant columns for display
bottom_10_high_quality_display = bottom_10_countries_high_quality[['Rank (from the bottom)', 'country', 'high_quality_articles_per_capita (per million)']]

# Display the bottom 10 countries for high-quality articles in a table
print("Bottom 10 countries by high-quality articles per capita-->")
print(tabulate(bottom_10_high_quality_display, headers='keys', tablefmt='psql', showindex=False))

# Save the bottom 10 countries for high-quality articles to a CSV for later use
bottom_10_high_quality_display.to_csv('/Users/radhikasethi/Documents/github/data-512-homework-2/data/bottom_10_countries_by_high_quality.csv', index=False)

# Step 13: Geographic regions by total articles per capita
# Rank regions by total articles per capita and display the table
regions_by_total_coverage = region_stats.sort_values(by='total_articles_per_capita', ascending=False)
print("Geographic regions by total coverage-->")
print(tabulate(regions_by_total_coverage[['region', 'total_articles_per_capita']], headers='keys', tablefmt='psql', showindex=False))

# Step 14: Geographic regions by high-quality articles per capita
# Rank regions by high-quality articles per capita and display the table
regions_by_high_quality_coverage = region_stats.sort_values(by='high_quality_articles_per_capita', ascending=False)
print("Geographic regions by high-quality coverage-->")
print(tabulate(regions_by_high_quality_coverage[['region', 'high_quality_articles_per_capita']], headers='keys', tablefmt='psql', showindex=False))

# Save the region data for future reference
regions_by_total_coverage.to_csv('/Users/radhikasethi/Documents/github/data-512-homework-2/data/regions_by_total_coverage.csv', index=False)
regions_by_high_quality_coverage.to_csv('/Users/radhikasethi/Documents/github/data-512-homework-2/data/regions_by_high_quality_coverage.csv', index=False)
# Out:
# Top 10 countries by high-quality articles per capita-->
# +-----------------------+-----------------------+--------------------------------------------------+
# |   Rank (from the top) | country               |   high_quality_articles_per_capita (per million) |
# |-----------------------+-----------------------+--------------------------------------------------|
# |                     1 | montenegro            |                                           5      |
# |                     2 | luxembourg            |                                           2.8571 |
# |                     3 | albania               |                                           2.5926 |
# |                     4 | kosovo                |                                           2.3529 |
# |                     5 | maldives              |                                           1.6667 |
# |                     6 | lithuania             |                                           1.3793 |
# |                     7 | croatia               |                                           1.3158 |
# |                     8 | guyana                |                                           1.25   |
# |                     9 | palestinian territory |                                           1.0909 |
# |                    10 | slovenia              |                                           0.9524 |
# +-----------------------+-----------------------+--------------------------------------------------+
# Bottom 10 countries by high-quality articles per capita-->
# +--------------------------+---------------------+--------------------------------------------------+
# |   Rank (from the bottom) | country             |   high_quality_articles_per_capita (per million) |
# |--------------------------+---------------------+--------------------------------------------------|
# |                        1 | antigua and barbuda |                                                0 |
# |                        2 | bahamas             |                                                0 |
# |                        3 | barbados            |                                                0 |
# |                        4 | belize              |                                                0 |
# |                        5 | benin               |                                                0 |
# |                        6 | bhutan              |                                                0 |
# |                        7 | botswana            |                                                0 |
# |                        8 | cape verde          |                                                0 |
# |                        9 | chad                |                                                0 |
# |                       10 | china               |                                                0 |
# +--------------------------+---------------------+--------------------------------------------------+
# Geographic regions by total coverage-->
# +-----------------+-----------------------------+
# | region          |   total_articles_per_capita |
# |-----------------+-----------------------------|
# | NORTHERN EUROPE |                    6.8705   |
# | OCEANIA         |                    6.48649  |
# | CARIBBEAN       |                    5.95628  |
# | SOUTHERN EUROPE |                    5.26073  |
# | CENTRAL AMERICA |                    3.66472  |
# | WESTERN EUROPE  |                    2.74131  |
# | EASTERN EUROPE  |                    2.66341  |
# | WESTERN ASIA    |                    2.06161  |
# | SOUTHERN AFRICA |                    1.80088  |
# | EASTERN AFRICA  |                    1.38074  |
# | SOUTH AMERICA   |                    1.33882  |
# | CENTRAL ASIA    |                    1.31841  |
# | NORTHERN AFRICA |                    1.18015  |
# | WESTERN AFRICA  |                    1.17793  |
# | MIDDLE AFRICA   |                    1.13974  |
# | SOUTHEAST ASIA  |                    0.70023  |
# | SOUTH ASIA      |                    0.330179 |
# | EAST ASIA       |                    0.117745 |
# +-----------------+-----------------------------+
# Geographic regions by high-quality coverage-->
# +-----------------+------------------------------------+
# | region          |   high_quality_articles_per_capita |
# |-----------------+------------------------------------|
# | SOUTHERN EUROPE |                         0.349835   |
# | NORTHERN EUROPE |                         0.323741   |
# | CARIBBEAN       |                         0.245902   |
# | CENTRAL AMERICA |                         0.194932   |
# | EASTERN EUROPE  |                         0.14275    |
# | SOUTHERN AFRICA |                         0.11713    |
# | WESTERN EUROPE  |                         0.11583    |
# | WESTERN ASIA    |                         0.0914015  |
# | OCEANIA         |                         0.0900901  |
# | NORTHERN AFRICA |                         0.0664322  |
# | CENTRAL ASIA    |                         0.0621891  |
# | SOUTH AMERICA   |                         0.0447059  |
# | SOUTHEAST ASIA  |                         0.0443184  |
# | MIDDLE AFRICA   |                         0.0396432  |
# | EASTERN AFRICA  |                         0.0353504  |
# | WESTERN AFRICA  |                         0.0293918  |
# | SOUTH ASIA      |                         0.0103489  |
# | EAST ASIA       |                         0.00191975 |
# +-----------------+------------------------------------+
